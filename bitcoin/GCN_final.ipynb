# %% [markdown]
# Download the required packages and preprocessed Elliptic dataset from the given links.
#
# ## Note:
# We temporarily uploaded our nodes.csv data as a LFS object in GitHub, but I just got an email saying that my quota has been depleted. If you cannot run the code for data download, please download our nodes.csv data from https://drive.google.com/file/d/1xOxc6VN0qkLjqBES1SXDjX1Kku7MNxp3/view?usp=sharing. Thanks!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'axes.facecolor':'dimgrey', 'grid.color':'lightgrey'})

import numpy as np
import pandas as pd
import networkx as nx
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch_scatter
from torch_geometric.data import Data
print(torch.__version__)

# # The PyG built-in GCNConv
# from torch_geometric.nn import GCNConv
from torch_geometric.nn.conv import MessagePassing
import torch_geometric.transforms as T
from torch_geometric.utils import remove_self_loops, add_self_loops, softmax, degree

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,roc_auc_score
import scipy.sparse as scsp
from sklearn.cluster import KMeans
import copy
# Out:
# 2.3.1+cpu

# %%
url_data_e = (r'https://raw.githubusercontent.com/yuchenWYC/'
              r'Elliptic_dataset/master/edges.csv')
edges = pd.read_csv(url_data_e)

# url_data_n = (r'https://media.githubusercontent.com/media/yuchenWYC/'
#               r'Elliptic_dataset/master/nodes.csv')
nodes = pd.read_csv("nodes.csv")

# %% [markdown]
# We can take a look at how the preprocessed dataset looks like.

# %%
nodes.iloc[0:2, 0:10]
# Out:
#         txId  class  timestamp         2         3         4          5  \
# 0  232438397      0          1  0.163054  1.963790 -0.646376  12.409294
# 1  232029206      0          1 -0.005027  0.578941 -0.091383   4.380281
#
#           6         7          8
# 0 -0.063725  9.782742  12.414558
# 1 -0.063725  4.667146   0.851305

# %%
edges.head()
# Out:
#        txId1      txId2
# 0  232344069   27553029
# 1    3881097  232457116
# 2  232051089  232470704
# 3  230473487    7089694
# 4  231182296   14660781

# %% [markdown]
# # Time-Step Splitting Script

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def time_step_split_helper(new_nodes, new_edges):
    """
    Split the graph and store node features, edges (represented by adjacency list),
    and labels separately by timestamp t (from 1 to 49).

    Args:
        new_nodes     A dataframe of the node features
        new_edges     A dataframe of the graph's adjacency list

    Returns:
        features_t    A list of (|N_t|, d) feature matrices by timestamp
        edge_indices  A list of (2, |E_t|) adjacency list by timestamp
        labels_t      A list of (|N_t|) labels by timestamp
    """

    features =  torch.FloatTensor(new_nodes.iloc[:, 2:].to_numpy())
    times = new_nodes.iloc[:, 2].to_numpy()
    times = torch.LongTensor(times.reshape(len(times),))
    labels = new_nodes.iloc[:, 1].to_numpy()
    labels = torch.LongTensor(labels.reshape(len(labels),))

    nodes_id = new_nodes.iloc[:, 0].to_numpy()
    nodes_id = torch.LongTensor(nodes_id.reshape(len(nodes_id),))

    min_t = torch.min(times) # 1
    max_t = torch.max(times) # 49

    # Construct nodes of the directed graph for each time step;
    # features by time step are stored in "features_t"; labels by
    # time step are stored in "labels_t"
    features_t = []
    labels_t = []

    # Create a dictionary where
    # <key, value> = <node_id, <<idx, node_index_in_time_t_subgraph>, <t, time_t>>>.
    id2idx = {}
    for t in range(min_t, max_t + 1):
        features_t.append(features[times == t, :])
        labels_t.append(labels[times == t])
        nodes_t = nodes_id[times == t]
        for i in range(nodes_t.shape[0]):
            id2idx[nodes_t[i].item()] = {}
            id2idx[nodes_t[i].item()]['idx'] = i
            id2idx[nodes_t[i].item()]['t'] = t

    # Construct adjacency lists of the directed graph (non-symmetric) for each time step;
    # adjacency lists for each time step are stored in "edge_indices".
    edge_idx_t = [[] for _ in range(min_t, max_t + 1)]
    for index in range(new_edges.shape[0]):
        node1_t = id2idx[new_edges.iloc[index, 0]]['t']
        node1_idx = id2idx[new_edges.iloc[index, 0]]['idx']
        node2_t = id2idx[new_edges.iloc[index, 1]]['t']
        node2_idx = id2idx[new_edges.iloc[index, 1]]['idx']
        edge_idx_t[node1_t - 1].append([node1_idx, node2_idx]) # time_step starts from 1

    edge_indices = [torch.LongTensor(edge_idx_t[i]).t() for i in range(len(edge_idx_t))]
    return features_t, edge_indices, labels_t

# %%
def time_step_split(new_nodes, new_edges, device, train_lt = 31, val_lt = 36, test_lt = 49):
    """
    Create and return the training, validation, and test set, splitted by time step,
    where each subgraph at time t is considered as an input of GCN model.

    Args:
        new_nodes     A dataframe of the node features
        new_edges     A dataframe of the graph's adjacency list
        device        Computing device
        train_lt      The last time step index of training set
        val_lt        The last time step index of validation set
        test_lt       The last time step index of test set

    Returns:
        data          A dictionary that stores training, validation, and test set,
                        each value is a list of Data object
        graph_info    A matrix where each row contains information of the time-step subgraph
                      [time_step, num_of_nodes, num_of_edges, num_of_illicit_nodes]
    """
    features_t, edge_indices, labels_t = time_step_split_helper(new_nodes, new_edges)
    
    graph_info = np.zeros((len(labels_t), 4), dtype = np.int64)
    for t in range(len(labels_t)):
        graph_info[t, :] = np.array([t, features_t[t].shape[0], edge_indices[t].shape[1],
                                     labels_t[t][labels_t[t] == 1].shape[0]])
        
    train_idx, val_idx, test_idx = [np.arange(train_lt), np.arange(train_lt, val_lt),
                                    np.arange(val_lt, test_lt)]
    train_list = [Data(x = features_t[idx], edge_index = edge_indices[idx],
                       y = labels_t[idx]).to(device) for idx in train_idx ]
    val_list = [Data(x = features_t[idx], edge_index = edge_indices[idx],
                     y = labels_t[idx]).to(device) for idx in val_idx ]
    test_list = [Data(x = features_t[idx], edge_index = edge_indices[idx],
                      y = labels_t[idx]).to(device) for idx in test_idx ]
    data = {}
    data['train'] = train_list
    data['val'] = val_list
    data['test'] = test_list

    return data, graph_info

# %%
data, graph_info = time_step_split(nodes, edges, device)
for key in data:
  print(key, len(data[key]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 data, graph_info = time_step_split(nodes, edges, device)
#       2 for key in data:
#       3   print(key, len(data[key]))
#
# Cell In[54], line 21, in time_step_split(new_nodes, new_edges, device, train_lt, val_lt, test_lt)
#       2 """
#       3 Create and return the training, validation, and test set, splitted by time step,
#       4 where each subgraph at time t is considered as an input of GCN model.
#    (...)
#      18                   [time_step, num_of_nodes, num_of_edges, num_of_illicit_nodes]
#      19 """
#      20 features_t, edge_indices, labels_t = time_step_split_helper(new_nodes, new_edges)
# ---> 21 print(np.array(features_t).shape, np.array(edge_indices).shape, np.array(labels_t).shape)
#      23 graph_info = np.zeros((len(labels_t), 4), dtype = np.int64)
#      24 for t in range(len(labels_t)):
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (49,) + inhomogeneous part.

# %%
graph_info
# Out:
# array([[   0, 2147, 1924,   17],
#        [   1, 1117,  858,   18],
#        [   2, 1279,  727,   11],
#        [   3, 1440, 1169,   30],
#        [   4, 1882, 1491,    8],
#        [   5,  485,  209,    5],
#        [   6, 1203,  858,  102],
#        [   7, 1165, 1044,   67],
#        [   8,  778,  484,  248],
#        [   9,  972,  538,   18],
#        [  10,  696,  477,  131],
#        [  11,  506,  446,   16],
#        [  12,  809,  564,  291],
#        [  13,  417,  350,   43],
#        [  14,  618,  446,  147],
#        [  15,  530,  334,  128],
#        [  16,  811,  673,   99],
#        [  17,  389,  275,   52],
#        [  18,  745,  585,   80],
#        [  19,  900,  613,  260],
#        [  20,  641,  518,  100],
#        [  21, 1763, 1537,  158],
#        [  22, 1187, 1046,   53],
#        [  23, 1126,  961,  137],
#        [  24,  594,  559,  118],
#        [  25,  517,  346,   96],
#        [  26,  206,   58,   24],
#        [  27,  284,  150,   85],
#        [  28, 1174,  911,  329],
#        [  29,  524,  372,   83],
#        [  30,  710,  522,  106],
#        [  31, 1323,  997,  342],
#        [  32,  441,  429,   23],
#        [  33,  515,  427,   37],
#        [  34, 1341, 1002,  182],
#        [  35, 1708, 1148,   33],
#        [  36,  498,  423,   40],
#        [  37,  756,  653,  111],
#        [  38, 1183, 1055,   81],
#        [  39, 1211, 1180,  112],
#        [  40, 1132, 1048,  116],
#        [  41, 2154, 1443,  239],
#        [  42, 1370,  935,   24],
#        [  43, 1591, 1497,   24],
#        [  44, 1221, 1346,    5],
#        [  45,  712,  388,    2],
#        [  46,  846,  822,   22],
#        [  47,  471,  371,   36],
#        [  48,  476,  415,   56]])

# %%
def time_group_split(new_nodes, new_edges, device, train_lt = 31, val_lt = 36, test_lt = 49):
    """
    Create and return the training, validation, and test set, splitted by specific
    time step intervals, where the combination of subgraphs within the time step
    interval is considered as an input of GCN model.

    Args:
        new_nodes     A dataframe of the node features
        new_edges     A dataframe of the graph's adjacency list
        device        Computing device
        train_lt      The last time step index of training set
        val_lt        The last time step index of validation set
        test_lt       The last time step index of test set

    Returns:
        data          A dictionary that stores training, validation, and test set
                        each value is one Data object
    """
    features =  torch.FloatTensor(new_nodes.iloc[:, 2:].to_numpy())
    times = new_nodes.iloc[:, 2].to_numpy()
    times = torch.LongTensor(times.reshape(len(times),))
    labels = new_nodes.iloc[:, 1].to_numpy()
    labels = torch.LongTensor(labels.reshape(len(labels),))

    nodes_id = new_nodes.iloc[:, 0].to_numpy()
    nodes_id = torch.LongTensor(nodes_id.reshape(len(nodes_id),))
    train_idx, val_idx, test_idx = [np.arange(1, train_lt + 1),
                                    np.arange(train_lt + 1, val_lt + 1),
                                    np.arange(val_lt + 1, test_lt + 1)]
    data_names = {'train': train_idx, 'val': val_idx, 'test': test_idx}

    # Construct nodes of the directed graph for specific time step intervals.
    # Features are stored in the given dataset name (train/val/test) of a dictionary,
    # 'raw_data', with key "features"; labels are stored with key "labels".
    min_t = torch.min(times) # 1
    max_t = torch.max(times) # 49

    id2idx = {}
    raw_data = {}
    for name in data_names.keys():
        features_set = []
        labels_set = []
        Id_set = []
        set_index = data_names[name]
        for time in set_index:
            features_set.append(features[times == time, :])
            labels_set.append(labels[times == time])
            Id_set.append(nodes_id[times == time])
        features_set = torch.cat(features_set, 0)
        labels_set = torch.cat(labels_set, 0)
        Id_set = torch.cat(Id_set, 0)
        for i in range((Id_set).shape[0]):
            id2idx[Id_set[i].item()] = {}
            id2idx[Id_set[i].item()]['idx'] = i
            id2idx[Id_set[i].item()]['set_name'] = name
        raw_data[name] = {'features': features_set, 'labels': labels_set}


    # Construct adjacency lists of the directed graph (non-symmetric) for
    # specific time intervals. Adjacency lists are stored with key "edge_indices".
    edge_idx_set = {name: [] for name in data_names.keys()}
    for index in range(new_edges.shape[0]):
        node1_set = id2idx[new_edges.iloc[index, 0]]['set_name']
        node1_idx = id2idx[new_edges.iloc[index, 0]]['idx']
        node2_set = id2idx[new_edges.iloc[index, 1]]['set_name']
        node2_idx = id2idx[new_edges.iloc[index, 1]]['idx']
        edge_idx_set[node1_set].append([node1_idx, node2_idx]) # time_stamp starts from 1

    for name in data_names.keys():
        raw_data[name]['edge_indices'] = torch.LongTensor(edge_idx_set[name]).t()


    # Construct the training, validation, test set by 'raw_data' and store
    # in a dictionary, 'data'.
    data = {}
    for name in data_names.keys():
        data[name] = Data(x = raw_data[name]['features'],
                          edge_index = raw_data[name]['edge_indices'],
                          y = raw_data[name]['labels']).to(device)
    return data

# %%
data2 = time_group_split(nodes, edges, device)
data2
# Out:
# {'train': Data(x=[27615, 166], edge_index=[2, 21045], y=[27615]),
#  'val': Data(x=[5328, 166], edge_index=[2, 4003], y=[5328]),
#  'test': Data(x=[13621, 166], edge_index=[2, 11576], y=[13621])}

# %% [markdown]
# # Random Splitting Script

# %%
def random_split_transd(new_nodes, new_edges, train_size, test_size, device, seed = 42):
    """
    Create and return the training, validation, and test set by randomly splitting
    the node indices to these three sets. Keep edge_index known for all sets.

    Args:
        new_nodes     A dataframe of the node features
        new_edges     A dataframe of the graph's adjacency list
        train_size    The node size proportion in training set
        test_size     The node size proportion in test set
        device        Computing device
        seed          Random seed for data splitting

    Returns:
        data          A Data object that stores node features, edge_index, and labels
        dict          A dictionary that stores training, validation, test set node indices
    """
    features =  torch.FloatTensor(new_nodes.iloc[:, 2:].to_numpy())
    labels = new_nodes.iloc[:, 1].to_numpy()
    labels = torch.LongTensor(labels.reshape(len(labels),))
    nodes_id = new_nodes.iloc[:, 0].to_numpy()

    # Create a dictionary that maps nodeId to index in the dataframe.
    id2idx = {}
    for i in range(new_nodes.shape[0]):
        id2idx[new_nodes.iloc[i, 0]] = i

    # Construct edge_index with same node indexing as in features and labels
    edge_idx = np.zeros((2, new_edges.shape[0]), dtype = np.int64)
    for index in range(new_edges.shape[0]):
        node1 = id2idx[new_edges.iloc[index, 0]]
        node2 = id2idx[new_edges.iloc[index, 1]]
        edge_idx[:, index] = [node1, node2]
    edge_index = torch.LongTensor(edge_idx)

    train_index, test_index = train_test_split(np.arange(labels.shape[0]),
                                               test_size = 1 - train_size,
                                               random_state = 42)
    val_index, test_index = train_test_split(test_index,
                                             test_size = test_size / (1 - train_size),
                                             random_state = 42)

    # Construct the training, validation, test set and store
    # in a dictionary, 'data'.
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    data = Data(x = features, edge_index = edge_index, y = labels).to(device)

    return data, {'train': train_index, 'val': val_index, 'test': test_index}

# %%
node_sum = nodes.shape[0]
train_node_size = np.sum(graph_info[0: 31, 1]) / node_sum
test_node_size = np.sum(graph_info[36:, 1]) / node_sum
data3, split_idx3 = random_split_transd(nodes, edges, train_size = train_node_size,
                                        test_size = test_node_size, device = device)
data3
# Out:
# Data(x=[46564, 166], edge_index=[2, 36624], y=[46564])

# %%
train_node_size, test_node_size
# Out:
# (0.5930547203848466, 0.29252212009277556)

# %%
def random_split_ind(new_nodes, new_edges, train_size, test_size, device, seed = 42):
    """
    Create and return the training, validation, and test set by randomly splitting
    the node indices to these three sets. Keep only the node-induced edges within
    each set.

    Args:
        new_nodes     A dataframe of the node features
        new_edges     A dataframe of the graph's adjacency list
        train_size    The node size proportion in training set
        test_size     The node size proportion in test set
        device        Computing device
        seed          Random seed for data splitting

    Returns:
        data          A dictionary that stores training, validation, and test set
                        each value is one Data object
    """
    ## Create PyG graph separated by time (merge graphs in each set in train/val/test).
    features =  torch.FloatTensor(new_nodes.iloc[:, 2:].to_numpy())
    labels = new_nodes.iloc[:, 1].to_numpy()
    labels = torch.LongTensor(labels.reshape(len(labels),))

    nodes_id = new_nodes.iloc[:, 0].to_numpy()
    nodes_id = torch.LongTensor(nodes_id.reshape(len(nodes_id),))

    # Create random splitting node indices.
    nodes_id_train, nodes_id_test, train_idx, test_idx = \
        train_test_split(nodes_id, range(nodes_id.shape[0]), test_size = 1 - train_size,
                         random_state = seed)
    nodes_id_valid, nodes_id_test, val_idx, test_idx = \
        train_test_split(nodes_id_test, test_idx, test_size = test_size / (1 - train_size),
                         random_state = seed)
    features_set = {'train': features[train_idx], 'val': features[val_idx],
                    'test': features[test_idx]}
    labels_set = {'train': labels[train_idx], 'val': labels[val_idx],
                  'test': labels[test_idx]}

    # Find the induced edge indices by the given node indices.
    id2idx = {}
    for i in range(nodes_id_train.shape[0]):
        id2idx[int(nodes_id_train[i])] = (i, 'train')
    for i in range(nodes_id_valid.shape[0]):
        id2idx[int(nodes_id_valid[i])] = (i, 'val')
    for i in range(nodes_id_test.shape[0]):
        id2idx[int(nodes_id_test[i])] = (i, 'test')

    edge_index = {'train': [], 'val': [], 'test': []}
    for i in range(new_edges.shape[0]):
        node1 = id2idx[new_edges.iloc[i, 0]]
        node2 = id2idx[new_edges.iloc[i, 1]]
        if (node1[-1] == 'train' and node2[-1] == 'train'):
            edge_index['train'].append([node1[0], node2[0]])
        elif (node1[-1] == 'val' and node2[-1] == 'val'):
            edge_index['val'].append([node1[0], node2[0]])
        elif (node1[-1] == 'test' and node2[-1] == 'test'):
            edge_index['test'].append([node1[0], node2[0]])

    data = {}
    for name in ['train', 'val', 'test']:
        edge_index[name] = torch.LongTensor(edge_index[name]).t()
        data[name] = Data(x = features_set[name], edge_index = edge_index[name],
                          y = labels_set[name]).to(device)
    train_data = data['train']
    val_data = data['val']
    test_data = data['test']

    return data

# %%
data4 = random_split_ind(nodes, edges, train_size = train_node_size,
                         test_size = test_node_size, device = device)
data4
# Out:
# {'train': Data(x=[27615, 166], edge_index=[2, 12937], y=[27615]),
#  'val': Data(x=[5328, 166], edge_index=[2, 428], y=[5328]),
#  'test': Data(x=[13621, 166], edge_index=[2, 3205], y=[13621])}

# %% [markdown]
# # Community Splitting Script

# %%
def laplacian(A, alpha = 0.1):
    """
    Returns the Laplacian matrix of the given adjacency matrix. For the directed
    acyclic graph (not connected) with adjacency matrix A, we define a modified
    Laplacian matrix as follows:
            A_tilde = (1 - alpha) * (A + A^T) + alpha * 11^T
            L = I - D_tilde^{-1/2} A_tilde D_tilde^{-1/2}
    Args:
        A             Adjacency matrix of certain graph
        alpha         Smoothing constant that prevents isolated nodes

    Returns:
        L             Modified Laplacian matrix of the adjacency matrix A
    """
    # A is sparse, csr format
    A = (1 - alpha) * (A + A.T) + alpha * scsp.csr_matrix(np.outer(np.ones(A.shape[0]), np.ones(A.shape[0])))
    D = scsp.diags(np.asarray(np.sum(A, axis = 0)).reshape(-1) ** (-1/2))
    L = scsp.diags(np.ones(A.shape[0])) - D @ A @ D
    return L

def adj_list_to_mtx(n, edge_index):
    """
    Create a csr-format adjacency matrix by the given adjacency list.
    Args:
        n             The number of nodes in the graph
        edge_index    The (2, |E|) adjacency list of the graph

    Returns:
        a csr-format adjacency matrix
    """
    edge_mtx = np.zeros((n, n))
    for i in range(edge_index.shape[1]):
        node1 = int(edge_index[0, i])
        node2 = int(edge_index[1, i])
        edge_mtx[node1, node2] = 1

    return scsp.csr_matrix(edge_mtx)

def nearest_sum(arr, target):
    """
    Get a combination of numbers in the given array that sums nearest to
    the target number.

    Args:
        arr      The given array
        target   The target number

    Returns:
        resid           The residual between the summation and the target number
        elt_idx_list    The indices of the subarray for summation
    """

    n = len(arr)
    opt_arr = np.zeros((n + 1, target + 1))
    for i in range(1, n + 1):
        opt_arr[i, :] = opt_arr[i-1, :]
        for j in np.arange(target, 0, step = -1):
            if opt_arr[i, j] > 0 and j + arr[i - 1] <= target:
                opt_arr[i, j + arr[i - 1]] += 1
        opt_arr[i, arr[i - 1]] += 1

    elt_list = []
    elt_idx_list = []
    target_sum = target
    idx = n
    if (opt_arr[idx, target] == 0):
        while opt_arr[idx, target_sum] == 0:
            print(target_sum)
            target_sum -= 1
    resid = target - target_sum

    while (idx > 0 and target_sum != 0):
        if (opt_arr[idx, target_sum] - opt_arr[idx - 1, target_sum] > 0):
            elt_list.append(arr[idx - 1])
            elt_idx_list.append(idx - 1)
            target_sum -= arr[idx - 1]
        idx = idx - 1
    return resid, elt_idx_list

# %%
def community_split_transd(new_nodes, new_edges, train_size, test_size, device):
    """
    Create and return the training, validation, and test set by merging small
    clusters of the graphs. Keep edge_index known for all sets.

    Args:
        new_nodes     A dataframe of the node features
        new_edges     A dataframe of the graph's adjacency list
        train_size    The node size proportion in training set
        test_size     The node size proportion in test set

    Returns:
        data          A Data object that stores node features, edge_index, and labels
        dict          A dictionary that stores training, validation, test set node indices
    """
    cluster_num = 500
    features_t, edge_indices, labels_t = time_step_split_helper(new_nodes, new_edges)

     # Construct the features, labels, and edge_index
    features =  torch.FloatTensor(new_nodes.iloc[:, 2:].to_numpy())
    labels = new_nodes.iloc[:, 1].to_numpy()
    labels = torch.LongTensor(labels.reshape(len(labels),))
    nodes_id = new_nodes.iloc[:, 0].to_numpy()
    # Create a dictionary that maps nodeId to index in the dataframe.
    id2idx = {}
    for i in range(new_nodes.shape[0]):
        id2idx[new_nodes.iloc[i, 0]] = i
    # Construct edge_index with same node indexing as in features and labels
    edge_idx = np.zeros((2, new_edges.shape[0]), dtype = np.int64)
    for index in range(new_edges.shape[0]):
        node1 = id2idx[new_edges.iloc[index, 0]]
        node2 = id2idx[new_edges.iloc[index, 1]]
        edge_idx[:, index] = [node1, node2]
    edge_index = torch.LongTensor(edge_idx)

    # Perform spectral clustering on the entire graph.
    # Since the entire graph's adjacency matrix A can be written as a block
    # diagonal matrix (blocked by time steps), we can recreate the eigenvalues
    # and eigenvectors of A by the eigenvalues and eigenvectors of blocks A_1,
    # A_2, ..., A_49 of A.
    t = 0
    eval_dict = {}
    node_num = []

    for t in range(49): # max_t = 49
        n = features_t[t].shape[0]
        A = adj_list_to_mtx(n, edge_indices[t])
        L = laplacian(A)
        evals, evecs = scsp.linalg.eigsh(L, k = n // 40, which = 'SM')

        for i in range(evals.shape[0]):
            eval_dict[evals[i]] = [t, i, evecs[:, i]]
        node_num.append(n)

    # 'node_blk' store node indices that mark time group separation.
    node_blk = np.insert(np.cumsum(node_num), 0, 0)
    # Block diagonal matrix has the first number-of-block (i.e., 49) smallest
    # eigenvalues to be 0.
    small_evals = np.sort(np.array([*eval_dict]))[49: (49 + cluster_num)]

    node_mtx = np.zeros((node_blk[-1], cluster_num))
    for i in range(small_evals.shape[0]):
        eval = small_evals[i]
        t, _, evec = eval_dict[eval]
        node_mtx[node_blk[t]: node_blk[t + 1], i] = evec

    # Use K-means algorithm to create certain number of clusters (e.g., 500).
    kmeans = KMeans(n_clusters = cluster_num, init = 'random', random_state = 42,
                    n_init = 3, max_iter = 10).fit(node_mtx)

    comm_count = np.bincount(kmeans.labels_)

    # Split and merge the clusters into three sets by the given number of nodes
    # in each set.
    node_num = new_nodes.shape[0]
    train_num = int(np.round(node_sum * train_size))
    val_num = int(np.round(node_sum * (1 - train_size - test_size)))

    train_num_resid, train_clust_idx = nearest_sum(comm_count, train_num)
    val_test_comm_count = np.delete(comm_count, train_clust_idx)
    val_test_clust_idx = np.delete(np.arange(500), train_clust_idx)

    val_num_resid, val_clust_idx_tmp = nearest_sum(val_test_comm_count, val_num)
    val_clust_idx = val_test_clust_idx[val_clust_idx_tmp]
    test_clust_idx = np.delete(np.arange(500), np.hstack((train_clust_idx, val_clust_idx)))

    # Split node indices by their clusters into three datasets.
    train_idx = []
    val_idx = []
    test_idx = []

    train_clust_set = set(train_clust_idx)
    val_clust_set = set(val_clust_idx)
    test_clust_set = set(test_clust_idx)
    for i in range(len(kmeans.labels_)):
        if kmeans.labels_[i] in train_clust_set:
            train_idx.append(i)
        elif kmeans.labels_[i] in val_clust_set:
            val_idx.append(i)
        else:
            test_idx.append(i)

    if train_num_resid > 0:
        train_idx.append(test_idx[-train_num_resid:])
        test_idx = test_idx[:-train_num_resid]
    if val_num_resid > 0:
        val_idx.append(test_idx[-val_num_resid:])
        test_idx = test_idx[:-val_num_resid]

    train_idx = np.array(train_idx)
    val_idx = np.array(val_idx)
    test_idx = np.array(test_idx)

    # Construct the training, validation, test set and store
    # in a dictionary, 'data'.
    data = Data(x = features, edge_index = edge_index, y = labels).to(device)

    return data, {'train': train_idx, 'val': val_idx, 'test': test_idx}

# %%
data5, split_idx5 = community_split_transd(nodes, edges, train_size = train_node_size,
                                    test_size = test_node_size, device = device)
data5
# Out:
# Data(x=[46564, 166], edge_index=[2, 36624], y=[46564])

# %% [markdown]
# # GCN Model

# %%
class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers,
                 dropout, return_embeds = False):
        """
        Initialize a GCN model.
        Args:
            input_dim       Input dimension of node embeddings
            hidden_dim      Hidden dimension of node embeddings
            output_dim      Output dimension of node embeddings
            num_layers      The number of GCN layers
            dropout         The dropout ratio in (0, 1]
                              (dropout: the probability of an element getting zeroed)
            return_embeds   A boolean value determining whether we skip the
                              classification layer and return node embeddings
        """

        super(GCN, self).__init__()

        # Construct all convs
        self.num_layers = num_layers
        self.convs = torch.nn.ModuleList([GCNLayer(hidden_dim, hidden_dim, directed = False)
                                                        for i in range(self.num_layers-1)])

        # Construct batch normalization
        self.bns = torch.nn.ModuleList([torch.nn.BatchNorm1d(hidden_dim)
                                        for i in range(self.num_layers-1)])
        # First GCN layer
        self.convs[0] = GCNLayer(input_dim, hidden_dim, directed = False)
        # Last GCN layer
        self.last_conv = GCNLayer(hidden_dim, output_dim, directed = False)
        self.softmax = torch.nn.LogSoftmax(dim = -1)

        self.dropout = dropout
        self.return_embeds = return_embeds

    def reset_parameters(self):
        """
        Reset all learnable parameters in GCN layers and Batch Normalization
        Layers.
        """
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()

    def forward(self, x, edge_index):
        """
        Produce a forward propagation of GCN model. Before the last GCN layer,
        we transform the embedding (x) in the following sequence:
          x -> GCN_Layer -> Batch_Norm -> ReLU -> Dropout.
        At the last GCN layer, the following sequence is applied:
          x -> GCN Layer -> Softmax -> output.

        Args:
            x             The node embedding
            edge_index    The adjacency list of the graph

        Returns:
            out           The predictions of labels / the updated node embedding
        """
        x = torch.clone(x.detach())
        for l in range(self.num_layers - 1):
            # Unweighted graph has weight 1.
            x = self.convs[l](x, edge_index, torch.ones(edge_index.shape[1]))
            x = self.bns[l](x)
            x = F.relu(x)
            x = F.dropout(x, p = self.dropout, training = self.training)

        x = self.last_conv(x, edge_index, torch.ones(edge_index.shape[1]))
        if self.return_embeds:
            out = x
        else:
            out = self.softmax(x)

        return out

# %%
class GCNLayer(MessagePassing):
    def __init__(self, in_channels, out_channels, bias = True,
                 directed = False, self_loop = True, **kwargs):
        """
        Initialize a GCN layer.
        Args:
            in_channels      In-channel dimension of node embeddings
            out_channels     Out-channel dimension of node embeddings
            bias             A boolean value determining whether we add a
                                learnable bias term in linear transformation
            directed         A boolean value determining whether we use directed
                                message passing D^{-1}A or use symmetric normalized
                                adjacency matrix D^{-1/2}AD^{-1/2}
            self_loop        A boolean value determining whether we add a self-
                                loop for each node
        """
        super(GCNLayer, self).__init__(**kwargs, aggr = 'add')

        self.in_channels = in_channels
        self.out_channels = out_channels

        self.directed = directed
        self.self_loop = self_loop

        # Define the layers needed for the message and update functions below.
        # self.lin is the linear transformation that we apply to the embedding.
        self.lin = nn.Linear(self.in_channels, self.out_channels, bias = bias)

        self.reset_parameters()

    def reset_parameters(self):
        """
        Reset all learnable parameters in the linear transformation.
        """
        self.lin.reset_parameters()

    def forward(self, x, edge_index, edge_weight):
        """
        Produce a forward propagation of GCN layer.

        Args:
            x             The node embedding
            edge_index    The (2, |E|) adjacency list of the graph
            edge_weight   The (|E|) vector specifying the edge weights in the graph
                            (for unweighted graph, edge weight is 1)

        Returns:
            An updated node embedding
        """
        # Add self-loops to the adjacency matrix.
        if self.self_loop:
            edge_index, _ = add_self_loops(edge_index, num_nodes = x.size(0))
            edge_weight = torch.cat((edge_weight, torch.ones(x.size(0))), dim = -1)

        # Apply linear transformation on node features.
        x = self.lin(x)

        # Compute normalization by updated node degree.
        if self.directed:
            row , _ = edge_index
            deg = degree(row, x.size(0), dtype = x.dtype) # only out-degree
            deg_inv = deg.pow(-1)
            deg_inv[deg_inv == float('inf')] = 0
            norm = deg_inv[row]
        else:
            row, col = edge_index
            deg = degree(col, x.size(0), dtype = x.dtype)
            deg_inv_sqrt = deg.pow(-0.5)
            deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
            norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

        return self.propagate(edge_index, x = (x, x), norm = norm, edge_weight = edge_weight)

    def message(self, x_j, edge_weight, norm):
        """
        Send the message of the neighboring node (i.e., x_j) to the source node (i.e., x_i).

        Args:
            x_j           The embedding of the neighboring node of source node x_i
            edge_weight   The edge weight of certain edge
            norm          Normalization constant determined by self.directed

        Returns:
            A message sending from the neighboring node to the source node
        """
        return norm.view(-1, 1) * x_j * edge_weight.view(-1, 1)

# %%
def train_ind_time_step(model, train_data, optimizer, loss_fn):
    """
    Train the model by using the given optimizer and loss_fn.

    Args:
        model       The GCN model
        train_data  The Data object that stores x, edge_index, and labels
                      only for training set
        optimizer   The optimizer
        loss_fn     The loss function

    Returns
        The average prediction loss of each time step in the training set
          by the given loss function
    """
    model.train()
    loss = torch.FloatTensor([0]*len(train_data)).to(device)
    optimizer.zero_grad()
    for i, data_t in enumerate(train_data):
        train_slice = model.forward(data_t.x, data_t.edge_index)
        train_label = data_t.y
        loss[i] = loss_fn(train_slice, train_label)
    loss.mean().backward()
    optimizer.step()
    return loss.mean().item()

# %%
def train_ind(model, train_data, optimizer, loss_fn):
    """
    Train the model by using the given optimizer and loss_fn.

    Args:
        model       The GCN model
        train_data  The Data object that stores x, edge_index, and labels
                      only for training set
        optimizer   The optimizer
        loss_fn     The loss function

    Returns
        The prediction loss by the given loss function
    """
    model.train()
    loss = 0

    optimizer.zero_grad()
    train_slice = model.forward(train_data.x, train_data.edge_index)
    train_label = train_data.y
    loss = loss_fn(train_slice, train_label)

    loss.backward()
    optimizer.step()

    return loss.item()

# %%
def train_transd(model, data, train_idx, optimizer, loss_fn):
    """
    Train the model by using the given optimizer and loss_fn.

    Args:
        model       The GCN model
        data        The Data object that stores x, edge_index, and labels
        train_idx   The node indices in the training set
        optimizer   The optimizer
        loss_fn     The loss function

    Returns
        The prediction loss by the given loss function
    """
    model.train()
    loss = 0

    optimizer.zero_grad()
    train_slice = model.forward(data.x, data.edge_index)[train_idx]
    train_label = data.y[train_idx]
    loss = loss_fn(train_slice, train_label)

    loss.backward()
    optimizer.step()
    return loss.item()

# %%
@torch.no_grad()
def test_ind_time_step(model, data, save_model_results=False):
    """
    Test the model by using the given splitted datasets.

    Args:
        model                 The GCN model
        data                  A dictionary of Data objects that store x, edge_index, and labels
                                for three sets
        save_model_results    A boolean determining whether we save the model results

    Returns
        The accuracy and auc-roc score of training, validation, and test set
    """

    model.eval()
    # The output of model on each data sets
    eval = {}
    for name in data.keys():
        data_list = data[name]
        eval_report = []
        eval_auc_roc = 0
        for i,data_i in enumerate(data_list):
            out = model.forward(data_i.x, data_i.edge_index)
            y_pred = out.argmax(dim=-1, keepdim=True)
            acc = classification_report(torch.unsqueeze(data_i.y, -1),
                                        y_pred,output_dict=True, zero_division=0)
            eval_report.append(acc)
            auc_roc = roc_auc_score(torch.unsqueeze(data_i.y, -1),y_pred)
            eval_auc_roc += auc_roc
        report = {}
        for key in eval_report[0].keys():
            if type(eval_report[0][key]) is dict:
                df = pd.DataFrame([sub_report[key] for sub_report in eval_report])
                report[key] = df.mean().to_dict()
            else:
                report[key] = np.mean(np.array([sub_report[key] for sub_report in eval_report]))
        eval_auc_roc /= len(data_list)
        eval[name] = {'report': pd.DataFrame(report), 'auc_roc': eval_auc_roc}

    ### TODO: what is the criterion to save the model results, the whole prediction
    ### y_pred and y_true? or only the test sets' prediction?
    if save_model_results:
        print ("Saving Model Predictions")

        data_new = {}
        data_new ['y_pred'] = y_pred.view(-1).cpu().detach().numpy()

        df = pd.DataFrame(data=data_new )
        # Save locally as csv
        df.to_csv('gcn_ind.csv', sep=',', index=False)

    return eval['train']['report'], eval['val']['report'], eval['test']['report'], \
           eval['train']['auc_roc'], eval['val']['auc_roc'], eval['test']['auc_roc']

# %%
@torch.no_grad()
def test_ind(model, data, save_model_results=False):
    """
    Test the model by using the given splitted datasets.

    Args:
        model                 The GCN model
        data                  A dictionary of Data objects that store x, edge_index, and labels
                                for three sets
        save_model_results    A boolean determining whether we save the model results

    Returns
        The accuracy and auc-roc score of training, validation, and test set
    """

    model.eval()
    # The output of model on each data sets
    train_out = model.forward(data['train'].x, data['train'].edge_index)
    train_pred = train_out.argmax(dim=-1, keepdim=True)
    train_acc = classification_report(torch.unsqueeze(data['train'].y, -1),
                                      train_pred, zero_division=0)
    train_auc_roc = roc_auc_score(torch.unsqueeze(data['train'].y, -1),
                                  train_pred)

    val_out = model.forward(data['val'].x, data['val'].edge_index)
    val_pred = val_out.argmax(dim=-1, keepdim=True)
    val_acc = classification_report(torch.unsqueeze(data['val'].y, -1),
                                    val_pred, zero_division=0)
    val_auc_roc = roc_auc_score(torch.unsqueeze(data['val'].y, -1),
                                  val_pred)

    test_out = model.forward(data['test'].x, data['test'].edge_index)
    test_pred = test_out.argmax(dim=-1, keepdim=True)
    test_acc = classification_report(torch.unsqueeze(data['test'].y, -1),
                                     test_pred, zero_division=0)
    test_auc_roc = roc_auc_score(torch.unsqueeze(data['test'].y, -1),
                                  test_pred)

    ### TODO: what is the criterion to save the model results, the whole prediction
    ### y_pred and y_true? or only the test sets' prediction?
    if save_model_results:
        print ("Saving Model Predictions")

        data = {}
        data['y_pred'] = y_pred.view(-1).cpu().detach().numpy()

        df = pd.DataFrame(data=data)
        # Save locally as csv
        df.to_csv('gcn_ind.csv', sep=',', index=False)

    return train_acc, val_acc, test_acc, \
           train_auc_roc, val_auc_roc, test_auc_roc

# %%
@torch.no_grad()
def test_transd(model, data, split_idx, save_model_results=False):
    """
    Test the model by using the given split_idx.

    Args:
        model                 The GCN model
        data                  The Data object that stores x, edge_index, and labels
        split_idx             A dictionary that stores node indices for three sets
        save_model_results    A boolean determining whether we save the model results

    Returns
        The accuracy and auc-roc score of training, validation, and test set
    """

    model.eval()
    # The output of model on all data
    out = model.forward(data.x, data.edge_index)

    train_index = split_idx['train']
    val_index = split_idx['val']
    test_index = split_idx['test']

    y_pred = out.argmax(dim=-1, keepdim=True)
    train_acc = classification_report(torch.unsqueeze(data.y[train_index], -1),
                                      y_pred[train_index], zero_division=0)
    valid_acc = classification_report(torch.unsqueeze(data.y[val_index], -1),
                                      y_pred[val_index], zero_division=0)
    valid_accuracy = classification_report(torch.unsqueeze(data.y[val_index], -1),
                                      y_pred[val_index], output_dict=True,
                                      zero_division=0)['accuracy']
    test_acc = classification_report(torch.unsqueeze(data.y[test_index], -1),
                                     y_pred[test_index], zero_division=0)
    train_auc_roc = roc_auc_score(torch.unsqueeze(data.y[train_index], -1),
                                      y_pred[train_index])
    val_auc_roc = roc_auc_score(torch.unsqueeze(data.y[val_index], -1),
                                      y_pred[val_index])
    test_auc_roc = roc_auc_score(torch.unsqueeze(data.y[test_index], -1),
                                      y_pred[test_index])

    if save_model_results:
        print ("Saving Model Predictions")

        data = {}
        data['y_pred'] = y_pred.view(-1).cpu().detach().numpy()

        df = pd.DataFrame(data=data)
        # Save locally as csv
        df.to_csv('gcn_transd.csv', sep=',', index=False)

    return train_acc, valid_acc, test_acc, \
           train_auc_roc, val_auc_roc, test_auc_roc

# %%
args = {
    'device': device,
    'num_layers': 2,
    'hidden_dim': 256,
    'dropout': 0.5,
    'lr': 0.01,
    'epochs': 200,
    'label_weight': torch.Tensor([0.5, 0.5])
}
args
# Out:
# {'device': 'cpu',
#  'num_layers': 2,
#  'hidden_dim': 256,
#  'dropout': 0.5,
#  'lr': 0.01,
#  'epochs': 200,
#  'label_weight': tensor([0.5000, 0.5000])}

# %% [markdown]
# # Random split & community split - transductive
# Note: Feed "data5" into the model if we were to run community split, "data3" to run random split.

# %%
model = GCN(data5.x.shape[1], args['hidden_dim'],
            2, args['num_layers'], args['dropout']).to(device)

# %%
import copy

model.reset_parameters()

optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
loss_fn = torch.nn.NLLLoss(weight=args['label_weight'])

best_model = None
best_valid_auc = 0
best_result = None
losses = []

for epoch in range(1, 1 + args["epochs"]):
    # train with random split
    loss = train_transd(model, data3, split_idx3['train'], optimizer, loss_fn)
    losses.append(loss)
    result = test_transd(model, data3, split_idx3)
    train_acc, val_acc, test_acc, train_auc, val_auc, test_auc = result
    if val_auc > best_valid_auc:
        best_valid_auc = val_auc
        best_model = copy.deepcopy(model)
        best_result = [train_acc, val_acc, test_acc, train_auc, val_auc, test_auc]

    print('Epoch: {:02},'.format(epoch),
          'Loss:{:.4f}'.format(loss),
          'Train:\n{}\n'.format(train_acc),
          'Train_auc_roc: {}'.format(train_auc),
          '\n\n'
          'Valid:\n{}\n'.format(val_acc),
          'Val_auc_roc: {}'.format(val_auc),
          '\n\n'
          'Test:\n{}\n'.format(test_acc),
          'Test_auc_roc: {}'.format(test_auc),
          '\n'
          )
# Out:
# Epoch: 01, Loss:0.8228 Train:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     24915
#            1       0.33      0.05      0.09      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.62      0.52      0.52     27615
# weighted avg       0.85      0.90      0.86     27615
#
#  Train_auc_roc: 0.5210366356723973
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      4821
#            1       0.32      0.06      0.10       507
#
#     accuracy                           0.90      5328
#    macro avg       0.62      0.52      0.52      5328
# weighted avg       0.85      0.90      0.87      5328
#
#  Val_auc_roc: 0.5222731172422427
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     12283
#            1       0.28      0.04      0.07      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.59      0.52      0.51     13621
# weighted avg       0.84      0.90      0.86     13621
#
#  Test_auc_roc: 0.5152351549354187
#
# Epoch: 02, Loss:0.3004 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 03, Loss:0.2324 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 04, Loss:0.2471 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 05, Loss:0.2463 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 06, Loss:0.2323 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 07, Loss:0.2213 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 08, Loss:0.2132 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 09, Loss:0.2120 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       0.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.45      0.50      0.47     27615
# weighted avg       0.81      0.90      0.86     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.45      0.50      0.47     13621
# weighted avg       0.81      0.90      0.86     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 10, Loss:0.2104 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.50      0.48     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5003703703703704
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.50      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.70      0.50      0.47     13621
# weighted avg       0.86      0.90      0.86     13621
#
#  Test_auc_roc: 0.5003329854099757
#
# Epoch: 11, Loss:0.2106 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.50      0.48     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5011111111111111
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       0.67      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.78      0.50      0.48     13621
# weighted avg       0.88      0.90      0.86     13621
#
#  Test_auc_roc: 0.5007066774877037
#
# Epoch: 12, Loss:0.2090 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.00      0.01      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.50      0.48     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5016666666666667
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       1.00      0.00      0.01      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.95      0.50      0.48     13621
# weighted avg       0.91      0.90      0.86     13621
#
#  Test_auc_roc: 0.5014947683109118
#
# Epoch: 13, Loss:0.2063 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.00      0.01      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.50      0.48     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5020370370370371
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       1.00      0.00      0.01      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.95      0.50      0.48     13621
# weighted avg       0.91      0.90      0.86     13621
#
#  Test_auc_roc: 0.5018684603886397
#
# Epoch: 14, Loss:0.2024 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.00      0.00      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.50      0.48     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5011111111111111
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       1.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.95      0.50      0.48     13621
# weighted avg       0.91      0.90      0.86     13621
#
#  Test_auc_roc: 0.5011210762331838
#
# Epoch: 15, Loss:0.1981 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.00      0.01      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.50      0.48     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5024074074074074
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4821
#            1       0.00      0.00      0.00       507
#
#     accuracy                           0.90      5328
#    macro avg       0.45      0.50      0.48      5328
# weighted avg       0.82      0.90      0.86      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       1.00      0.00      0.00      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.95      0.50      0.48     13621
# weighted avg       0.91      0.90      0.86     13621
#
#  Test_auc_roc: 0.5007473841554559
#
# Epoch: 16, Loss:0.1944 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24915
#            1       1.00      0.02      0.05      2700
#
#     accuracy                           0.90     27615
#    macro avg       0.95      0.51      0.50     27615
# weighted avg       0.91      0.90      0.86     27615
#
#  Train_auc_roc: 0.5122222222222222
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      4821
#            1       1.00      0.02      0.03       507
#
#     accuracy                           0.91      5328
#    macro avg       0.95      0.51      0.49      5328
# weighted avg       0.92      0.91      0.86      5328
#
#  Val_auc_roc: 0.5078895463510849
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     12283
#            1       1.00      0.01      0.03      1338
#
#     accuracy                           0.90     13621
#    macro avg       0.95      0.51      0.49     13621
# weighted avg       0.91      0.90      0.86     13621
#
#  Test_auc_roc: 0.5071001494768311
#
# Epoch: 17, Loss:0.1911 Train:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     24915
#            1       0.97      0.09      0.17      2700
#
#     accuracy                           0.91     27615
#    macro avg       0.94      0.55      0.56     27615
# weighted avg       0.92      0.91      0.88     27615
#
#  Train_auc_roc: 0.5457854483020046
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      4821
#            1       0.98      0.08      0.15       507
#
#     accuracy                           0.91      5328
#    macro avg       0.94      0.54      0.55      5328
# weighted avg       0.92      0.91      0.88      5328
#
#  Val_auc_roc: 0.5403302121266794
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     12283
#            1       0.97      0.06      0.12      1338
#
#     accuracy                           0.91     13621
#    macro avg       0.94      0.53      0.54     13621
# weighted avg       0.91      0.91      0.87     13621
#
#  Test_auc_roc: 0.5320153986813474
#
# Epoch: 18, Loss:0.1878 Train:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     24915
#            1       0.94      0.20      0.32      2700
#
#     accuracy                           0.92     27615
#    macro avg       0.93      0.60      0.64     27615
# weighted avg       0.92      0.92      0.90     27615
#
#  Train_auc_roc: 0.5971355943541373
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4821
#            1       0.97      0.17      0.29       507
#
#     accuracy                           0.92      5328
#    macro avg       0.94      0.58      0.62      5328
# weighted avg       0.92      0.92      0.89      5328
#
#  Val_auc_roc: 0.5845014845062713
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     12283
#            1       0.94      0.18      0.30      1338
#
#     accuracy                           0.92     13621
#    macro avg       0.93      0.59      0.63     13621
# weighted avg       0.92      0.92      0.89     13621
#
#  Test_auc_roc: 0.587580730327514
#
# Epoch: 19, Loss:0.1866 Train:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     24915
#            1       0.93      0.30      0.45      2700
#
#     accuracy                           0.93     27615
#    macro avg       0.93      0.65      0.71     27615
# weighted avg       0.93      0.93      0.91     27615
#
#  Train_auc_roc: 0.6491261399870671
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      4821
#            1       0.95      0.27      0.43       507
#
#     accuracy                           0.93      5328
#    macro avg       0.94      0.64      0.69      5328
# weighted avg       0.93      0.93      0.91      5328
#
#  Val_auc_roc: 0.6362511644690574
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     12283
#            1       0.93      0.29      0.44      1338
#
#     accuracy                           0.93     13621
#    macro avg       0.93      0.64      0.70     13621
# weighted avg       0.93      0.93      0.91     13621
#
#  Test_auc_roc: 0.6431460619736807
#
# Epoch: 20, Loss:0.1825 Train:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     24915
#            1       0.92      0.37      0.53      2700
#
#     accuracy                           0.94     27615
#    macro avg       0.93      0.68      0.75     27615
# weighted avg       0.93      0.94      0.92     27615
#
#  Train_auc_roc: 0.683874395165786
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4821
#            1       0.90      0.36      0.51       507
#
#     accuracy                           0.94      5328
#    macro avg       0.92      0.68      0.74      5328
# weighted avg       0.93      0.94      0.92      5328
#
#  Val_auc_roc: 0.6774129210345764
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     12283
#            1       0.90      0.35      0.51      1338
#
#     accuracy                           0.93     13621
#    macro avg       0.92      0.67      0.74     13621
# weighted avg       0.93      0.93      0.92     13621
#
#  Test_auc_roc: 0.6743066206322323
#
# Epoch: 21, Loss:0.1797 Train:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     24915
#            1       0.90      0.43      0.58      2700
#
#     accuracy                           0.94     27615
#    macro avg       0.92      0.71      0.78     27615
# weighted avg       0.94      0.94      0.93     27615
#
#  Train_auc_roc: 0.7132322117421456
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      4821
#            1       0.88      0.42      0.57       507
#
#     accuracy                           0.94      5328
#    macro avg       0.91      0.71      0.77      5328
# weighted avg       0.94      0.94      0.93      5328
#
#  Val_auc_roc: 0.7081414030578742
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     12283
#            1       0.87      0.40      0.54      1338
#
#     accuracy                           0.93     13621
#    macro avg       0.90      0.69      0.75     13621
# weighted avg       0.93      0.93      0.92     13621
#
#  Test_auc_roc: 0.6948409744433925
#
# Epoch: 22, Loss:0.1770 Train:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     24915
#            1       0.88      0.47      0.61      2700
#
#     accuracy                           0.94     27615
#    macro avg       0.91      0.73      0.79     27615
# weighted avg       0.94      0.94      0.93     27615
#
#  Train_auc_roc: 0.732704082770308
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4821
#            1       0.85      0.46      0.60       507
#
#     accuracy                           0.94      5328
#    macro avg       0.90      0.73      0.78      5328
# weighted avg       0.94      0.94      0.93      5328
#
#  Val_auc_roc: 0.7275031942352798
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     12283
#            1       0.84      0.44      0.58      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.89      0.72      0.77     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.7170402553044318
#
# Epoch: 23, Loss:0.1750 Train:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     24915
#            1       0.86      0.51      0.64      2700
#
#     accuracy                           0.94     27615
#    macro avg       0.90      0.75      0.81     27615
# weighted avg       0.94      0.94      0.94     27615
#
#  Train_auc_roc: 0.7521759537984704
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4821
#            1       0.83      0.51      0.63       507
#
#     accuracy                           0.94      5328
#    macro avg       0.89      0.75      0.80      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.7499272782169725
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     12283
#            1       0.82      0.47      0.60      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.88      0.73      0.78     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.7294755034088335
#
# Epoch: 24, Loss:0.1723 Train:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     24915
#            1       0.84      0.54      0.66      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.90      0.77      0.81     27615
# weighted avg       0.94      0.95      0.94     27615
#
#  Train_auc_roc: 0.7654071621290164
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4821
#            1       0.80      0.52      0.63       507
#
#     accuracy                           0.94      5328
#    macro avg       0.88      0.76      0.80      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.7555860762026096
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     12283
#            1       0.80      0.51      0.62      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.87      0.75      0.79     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.7467353739239049
#
# Epoch: 25, Loss:0.1684 Train:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     24915
#            1       0.83      0.57      0.67      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.78      0.82     27615
# weighted avg       0.94      0.95      0.94     27615
#
#  Train_auc_roc: 0.7778173567908666
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      4821
#            1       0.79      0.55      0.65       507
#
#     accuracy                           0.94      5328
#    macro avg       0.87      0.77      0.81      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.7695492722298524
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     12283
#            1       0.79      0.53      0.63      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.87      0.76      0.80     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.7572134162362043
#
# Epoch: 26, Loss:0.1674 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     24915
#            1       0.82      0.60      0.69      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.79      0.83     27615
# weighted avg       0.94      0.95      0.94     27615
#
#  Train_auc_roc: 0.7930810310611635
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4821
#            1       0.80      0.59      0.68       507
#
#     accuracy                           0.95      5328
#    macro avg       0.88      0.79      0.82      5328
# weighted avg       0.94      0.95      0.94      5328
#
#  Val_auc_roc: 0.7862108453032773
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     12283
#            1       0.79      0.56      0.66      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.87      0.77      0.81     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7738740651309118
#
# Epoch: 27, Loss:0.1657 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     24915
#            1       0.82      0.62      0.70      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.80      0.84     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8004775124311548
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4821
#            1       0.79      0.60      0.69       507
#
#     accuracy                           0.95      5328
#    macro avg       0.88      0.79      0.83      5328
# weighted avg       0.94      0.95      0.94      5328
#
#  Val_auc_roc: 0.7935818270412115
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.79      0.58      0.67      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.87      0.78      0.82     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.78155877209219
#
# Epoch: 28, Loss:0.1631 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     24915
#            1       0.82      0.63      0.71      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.81      0.84     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8050469373648181
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4821
#            1       0.79      0.62      0.69       507
#
#     accuracy                           0.95      5328
#    macro avg       0.88      0.80      0.83      5328
# weighted avg       0.94      0.95      0.95      5328
#
#  Val_auc_roc: 0.8001740413305202
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.79      0.59      0.67      1338
#
#     accuracy                           0.94     13621
#    macro avg       0.87      0.78      0.82     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7842153233040379
#
# Epoch: 29, Loss:0.1613 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     24915
#            1       0.83      0.64      0.72      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.81      0.85     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8104930095658571
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4821
#            1       0.79      0.62      0.70       507
#
#     accuracy                           0.95      5328
#    macro avg       0.88      0.80      0.84      5328
# weighted avg       0.95      0.95      0.95      5328
#
#  Val_auc_roc: 0.803132621212177
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.80      0.59      0.68      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.88      0.79      0.83     13621
# weighted avg       0.94      0.95      0.94     13621
#
#  Test_auc_roc: 0.7879856186811113
#
# Epoch: 30, Loss:0.1590 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     24915
#            1       0.83      0.64      0.72      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.90      0.81      0.85     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8132817133810512
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4821
#            1       0.81      0.62      0.70       507
#
#     accuracy                           0.95      5328
#    macro avg       0.88      0.80      0.84      5328
# weighted avg       0.95      0.95      0.95      5328
#
#  Val_auc_roc: 0.8027687054540723
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.81      0.60      0.69      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.88      0.79      0.83     13621
# weighted avg       0.94      0.95      0.94     13621
#
#  Test_auc_roc: 0.7912601019772002
#
# Epoch: 31, Loss:0.1575 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     24915
#            1       0.84      0.64      0.73      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.90      0.81      0.85     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8143836822975896
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      4821
#            1       0.82      0.63      0.71       507
#
#     accuracy                           0.95      5328
#    macro avg       0.89      0.81      0.84      5328
# weighted avg       0.95      0.95      0.95      5328
#
#  Val_auc_roc: 0.8062458499488799
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.81      0.60      0.69      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.79      0.83     13621
# weighted avg       0.94      0.95      0.94     13621
#
#  Test_auc_roc: 0.7932913890368486
#
# Epoch: 32, Loss:0.1562 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     24915
#            1       0.85      0.65      0.73      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.91      0.82      0.85     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8165967623252393
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      4821
#            1       0.83      0.63      0.72       507
#
#     accuracy                           0.95      5328
#    macro avg       0.90      0.81      0.85      5328
# weighted avg       0.95      0.95      0.95      5328
#
#  Val_auc_roc: 0.8089442269950623
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     12283
#            1       0.82      0.60      0.70      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.79      0.83     13621
# weighted avg       0.94      0.95      0.94     13621
#
#  Test_auc_roc: 0.7949489840187692
#
# Epoch: 33, Loss:0.1543 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     24915
#            1       0.85      0.65      0.74      2700
#
#     accuracy                           0.95     27615
#    macro avg       0.91      0.82      0.86     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8189393939393939
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      4821
#            1       0.84      0.64      0.72       507
#
#     accuracy                           0.95      5328
#    macro avg       0.90      0.81      0.85      5328
# weighted avg       0.95      0.95      0.95      5328
#
#  Val_auc_roc: 0.8111240394280937
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     12283
#            1       0.82      0.61      0.70      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.80      0.84     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.7984750393893294
#
# Epoch: 34, Loss:0.1527 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     24915
#            1       0.86      0.66      0.75      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.82      0.86     27615
# weighted avg       0.95      0.96      0.95     27615
#
#  Train_auc_roc: 0.8246801346801347
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      4821
#            1       0.84      0.64      0.73       507
#
#     accuracy                           0.95      5328
#    macro avg       0.90      0.81      0.85      5328
# weighted avg       0.95      0.95      0.95      5328
#
#  Val_auc_roc: 0.8139789063871204
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     12283
#            1       0.82      0.62      0.71      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.80      0.84     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8043319926297201
#
# Epoch: 35, Loss:0.1508 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24915
#            1       0.85      0.68      0.76      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.83      0.87     27615
# weighted avg       0.95      0.96      0.95     27615
#
#  Train_auc_roc: 0.8320720449528397
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      4821
#            1       0.84      0.66      0.74       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.82      0.86      5328
# weighted avg       0.95      0.96      0.95      5328
#
#  Val_auc_roc: 0.8217647398155751
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.82      0.63      0.71      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.81      0.84     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.809238028375894
#
# Epoch: 36, Loss:0.1512 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24915
#            1       0.85      0.69      0.76      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.84      0.87     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.840294111088813
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.83      0.67      0.74       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.83      0.86      5328
# weighted avg       0.95      0.96      0.95      5328
#
#  Val_auc_roc: 0.8282532411822536
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.81      0.66      0.73      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.82      0.85     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8202118827691779
#
# Epoch: 37, Loss:0.1479 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24915
#            1       0.84      0.71      0.77      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.85      0.87     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8479405534372423
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4821
#            1       0.83      0.69      0.75       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.84      0.86      5328
# weighted avg       0.95      0.96      0.95      5328
#
#  Val_auc_roc: 0.836506703291443
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12283
#            1       0.81      0.67      0.73      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.83      0.85     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8276523497239431
#
# Epoch: 38, Loss:0.1470 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24915
#            1       0.83      0.72      0.77      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.90      0.85      0.87     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8514125805516535
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4821
#            1       0.83      0.71      0.76       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.85      0.87      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8462649233076689
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     12283
#            1       0.80      0.69      0.74      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.83      0.86     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8346784179332282
#
# Epoch: 39, Loss:0.1454 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24915
#            1       0.83      0.73      0.78      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.90      0.86      0.88     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8563770151849622
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4821
#            1       0.82      0.71      0.77       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.85      0.87      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8490160773440656
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     12283
#            1       0.80      0.69      0.74      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.88      0.84      0.86     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8373423012130343
#
# Epoch: 40, Loss:0.1453 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24915
#            1       0.83      0.73      0.78      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.90      0.86      0.88     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8582644324035051
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4821
#            1       0.82      0.71      0.77       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.85      0.87      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8490160773440656
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     12283
#            1       0.80      0.70      0.75      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.84      0.86     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8397065736826587
#
# Epoch: 41, Loss:0.1439 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24915
#            1       0.84      0.73      0.78      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.86      0.88     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8592058554641336
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4821
#            1       0.83      0.72      0.77       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.85      0.87      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8512996026997273
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     12283
#            1       0.81      0.70      0.75      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.84      0.86     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8401136403601805
#
# Epoch: 42, Loss:0.1424 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24915
#            1       0.85      0.73      0.78      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.86      0.88     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8585161772247865
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.84      0.72      0.77       507
#
#     accuracy                           0.96      5328
#    macro avg       0.90      0.85      0.88      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8507282610963621
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.82      0.70      0.75      1338
#
#     accuracy                           0.95     13621
#    macro avg       0.89      0.84      0.86     13621
# weighted avg       0.95      0.95      0.95     13621
#
#  Test_auc_roc: 0.8401470149599743
#
# Epoch: 43, Loss:0.1407 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24915
#            1       0.85      0.73      0.79      2700
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.86      0.88     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8590224541217919
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.84      0.72      0.78       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.85      0.88      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8530117864520238
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
# ...
#            1       0.87      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8811908265881777
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4821
#            1       0.84      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8733069939331009
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.83      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8577846238807341
#
# Epoch: 70, Loss:0.1190 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.881355943541374
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4821
#            1       0.85      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.873410706855731
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.857988157219495
#
# Epoch: 71, Loss:0.1217 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.77      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.881001070305706
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.85      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8724245135618455
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8576958784772712
#
# Epoch: 72, Loss:0.1198 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.77      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8803807389568978
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.85      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8725282264844756
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.91      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.857485013070552
#
# Epoch: 73, Loss:0.1190 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.77      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.93      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.880666265302027
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.85      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8715420331905899
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.91      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8571927343283284
#
# Epoch: 74, Loss:0.1193 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.88      0.77      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.93      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8814471425067452
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.85      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8724245135618455
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8574035997350477
#
# Epoch: 75, Loss:0.1172 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.93      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8822727272727272
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4821
#            1       0.85      0.76      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.87      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8724245135618455
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8585246759682316
#
# Epoch: 76, Loss:0.1179 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8834887506410685
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4821
#            1       0.84      0.77      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.88      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8750719546756117
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8595236321981587
#
# Epoch: 77, Loss:0.1175 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.883243360759917
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4821
#            1       0.84      0.77      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.88      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8750719546756117
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.73      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8594829255304066
#
# Epoch: 78, Loss:0.1167 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.87      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.92      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8836538675942649
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4821
#            1       0.84      0.77      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.88      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8760581479694974
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.74      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.8598566176081347
#
# Epoch: 79, Loss:0.1162 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     24915
#            1       0.88      0.78      0.82      2700
#
#     accuracy                           0.97     27615
#    macro avg       0.93      0.88      0.90     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.8831338774054005
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4821
#            1       0.84      0.77      0.80       507
#
#     accuracy                           0.96      5328
#    macro avg       0.91      0.88      0.89      5328
# weighted avg       0.96      0.96      0.96      5328
#
#  Val_auc_roc: 0.8761618608921277
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     12283
#            1       0.84      0.74      0.78      1338
#
#     accuracy                           0.96     13621
#    macro avg       0.90      0.86      0.88     13621
# weighted avg       0.96      0.96      0.96     13621
#
#  Test_auc_roc: 0.860352429689119
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 17
#      15 loss = train_transd(model, data3, split_idx3['train'], optimizer, loss_fn)
#      16 losses.append(loss)
# ---> 17 result = test_transd(model, data3, split_idx3)
#      18 train_acc, val_acc, test_acc, train_auc, val_auc, test_auc = result
#      19 if val_auc > best_valid_auc:
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[28], line 18, in test_transd(model, data, split_idx, save_model_results)
#      16 model.eval()
#      17 # The output of model on all data
# ---> 18 out = model.forward(data.x, data.edge_index)
#      20 train_index = split_idx['train']
#      21 val_index = split_idx['val']
#
# Cell In[21], line 65, in GCN.forward(self, x, edge_index)
#      62 for l in range(self.num_layers - 1):
#      63     # Unweighted graph has weight 1.
#      64     x = self.convs[l](x, edge_index, torch.ones(edge_index.shape[1]))
# ---> 65     x = self.bns[l](x)
#      66     x = F.relu(x)
#      67     x = F.dropout(x, p = self.dropout, training = self.training)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py:175, in _BatchNorm.forward(self, input)
#     168     bn_training = (self.running_mean is None) and (self.running_var is None)
#     170 r"""
#     171 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     172 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     173 used for normalization (i.e. in eval mode when buffers are not None).
#     174 """
# --> 175 return F.batch_norm(
#     176     input,
#     177     # If buffers are not to be tracked, ensure that they won't be updated
#     178     self.running_mean
#     179     if not self.training or self.track_running_stats
#     180     else None,
#     181     self.running_var if not self.training or self.track_running_stats else None,
#     182     self.weight,
#     183     self.bias,
#     184     bn_training,
#     185     exponential_average_factor,
#     186     self.eps,
#     187 )
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:2509, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2506 if training:
#    2507     _verify_batch_size(input.size())
# -> 2509 return torch.batch_norm(
#    2510     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2511 )
#
# KeyboardInterrupt:

# %% [markdown]
# # Time group split - inductive

# %%
model = GCN(data2['train'].x.shape[1], args['hidden_dim'],
            2, args['num_layers'], args['dropout']).to(device)

# %%
model.reset_parameters()

optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
loss_fn = torch.nn.NLLLoss(weight=args['label_weight'])

best_model = None
best_valid_auc = 0
best_result = None
losses = []

for epoch in range(1, 1 + args["epochs"]):
    # train with random split
    loss = train_ind(model, data2['train'], optimizer, loss_fn)
    losses.append(loss)
    result = test_ind(model, data2)
    train_acc, val_acc, test_acc, train_auc, val_auc, test_auc = result
    if val_auc > best_valid_auc:
        best_valid_auc = val_auc
        best_model = copy.deepcopy(model)
        best_result = [train_acc, val_acc, test_acc, train_auc, val_auc, test_auc]

    print('Epoch: {:02},'.format(epoch),
          'Loss:{:.4f}'.format(loss),
          'Train:\n{}\n'.format(train_acc),
          'Train_auc_roc: {}'.format(train_auc),
          '\n\n'
          'Valid:\n{}\n'.format(val_acc),
          'Val_auc_roc: {}'.format(val_auc),
          '\n\n'
          'Test:\n{}\n'.format(test_acc),
          'Test_auc_roc: {}'.format(test_auc),
          '\n'
          )
# Out:
# Epoch: 01, Loss:0.6482 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.94     24555
#            1       0.73      0.08      0.15      3060
#
#     accuracy                           0.90     27615
#    macro avg       0.81      0.54      0.55     27615
# weighted avg       0.88      0.90      0.86     27615
#
#  Train_auc_roc: 0.5397729586642233
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 02, Loss:0.2736 Train:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     24555
#            1       0.00      0.00      0.00      3060
#
#     accuracy                           0.89     27615
#    macro avg       0.44      0.50      0.47     27615
# weighted avg       0.79      0.89      0.84     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 03, Loss:0.2447 Train:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     24555
#            1       0.00      0.00      0.00      3060
#
#     accuracy                           0.89     27615
#    macro avg       0.44      0.50      0.47     27615
# weighted avg       0.79      0.89      0.84     27615
#
#  Train_auc_roc: 0.5
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 04, Loss:0.2372 Train:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     24555
#            1       1.00      0.00      0.00      3060
#
#     accuracy                           0.89     27615
#    macro avg       0.94      0.50      0.47     27615
# weighted avg       0.90      0.89      0.84     27615
#
#  Train_auc_roc: 0.5003267973856209
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 05, Loss:0.2203 Train:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     24555
#            1       0.71      0.01      0.02      3060
#
#     accuracy                           0.89     27615
#    macro avg       0.80      0.51      0.48     27615
# weighted avg       0.87      0.89      0.84     27615
#
#  Train_auc_roc: 0.505270481232607
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 06, Loss:0.2098 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24555
#            1       0.88      0.10      0.17      3060
#
#     accuracy                           0.90     27615
#    macro avg       0.89      0.55      0.56     27615
# weighted avg       0.90      0.90      0.86     27615
#
#  Train_auc_roc: 0.5472247176207075
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 07, Loss:0.2064 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24555
#            1       0.86      0.14      0.24      3060
#
#     accuracy                           0.90     27615
#    macro avg       0.88      0.57      0.59     27615
# weighted avg       0.90      0.90      0.87     27615
#
#  Train_auc_roc: 0.5675696016545491
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 08, Loss:0.2031 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24555
#            1       0.86      0.12      0.21      3060
#
#     accuracy                           0.90     27615
#    macro avg       0.88      0.56      0.58     27615
# weighted avg       0.90      0.90      0.87     27615
#
#  Train_auc_roc: 0.5598486391094821
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 09, Loss:0.1987 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24555
#            1       0.88      0.09      0.16      3060
#
#     accuracy                           0.90     27615
#    macro avg       0.89      0.54      0.55     27615
# weighted avg       0.90      0.90      0.86     27615
#
#  Train_auc_roc: 0.5427310040285712
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 10, Loss:0.1955 Train:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     24555
#            1       0.90      0.12      0.21      3060
#
#     accuracy                           0.90     27615
#    macro avg       0.90      0.56      0.58     27615
# weighted avg       0.90      0.90      0.86     27615
#
#  Train_auc_roc: 0.5572327627854238
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.00      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.44      0.50      0.47      5328
# weighted avg       0.78      0.88      0.83      5328
#
#  Val_auc_roc: 0.5
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 11, Loss:0.1910 Train:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     24555
#            1       0.94      0.27      0.41      3060
#
#     accuracy                           0.92     27615
#    macro avg       0.93      0.63      0.68     27615
# weighted avg       0.92      0.92      0.90     27615
#
#  Train_auc_roc: 0.6318866011075576
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.50      0.00      0.00       617
#
#     accuracy                           0.88      5328
#    macro avg       0.69      0.50      0.47      5328
# weighted avg       0.84      0.88      0.83      5328
#
#  Val_auc_roc: 0.5007042381928292
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.5
#
# Epoch: 12, Loss:0.1868 Train:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     24555
#            1       0.91      0.45      0.60      3060
#
#     accuracy                           0.93     27615
#    macro avg       0.93      0.72      0.78     27615
# weighted avg       0.93      0.93      0.92     27615
#
#  Train_auc_roc: 0.7206165830209094
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4711
#            1       0.38      0.00      0.01       617
#
#     accuracy                           0.88      5328
#    macro avg       0.63      0.50      0.47      5328
# weighted avg       0.83      0.88      0.83      5328
#
#  Val_auc_roc: 0.501900445421196
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.94     13621
#    macro avg       0.47      0.50      0.48     13621
# weighted avg       0.88      0.94      0.91     13621
#
#  Test_auc_roc: 0.4999607935387752
#
# Epoch: 13, Loss:0.1809 Train:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     24555
#            1       0.87      0.57      0.69      3060
#
#     accuracy                           0.94     27615
#    macro avg       0.91      0.78      0.83     27615
# weighted avg       0.94      0.94      0.94     27615
#
#  Train_auc_roc: 0.779243974111738
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94      4711
#            1       0.64      0.11      0.19       617
#
#     accuracy                           0.89      5328
#    macro avg       0.77      0.55      0.56      5328
# weighted avg       0.86      0.89      0.85      5328
#
#  Val_auc_roc: 0.5502618617002794
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.38      0.01      0.01       868
#
#     accuracy                           0.94     13621
#    macro avg       0.66      0.50      0.49     13621
# weighted avg       0.90      0.94      0.91     13621
#
#  Test_auc_roc: 0.5025665326419988
#
# Epoch: 14, Loss:0.1777 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     24555
#            1       0.83      0.66      0.74      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.82      0.85     27615
# weighted avg       0.94      0.95      0.94     27615
#
#  Train_auc_roc: 0.8218597905462328
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      4711
#            1       0.67      0.26      0.38       617
#
#     accuracy                           0.90      5328
#    macro avg       0.79      0.62      0.66      5328
# weighted avg       0.88      0.90      0.88      5328
#
#  Val_auc_roc: 0.6219792499157977
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     12753
#            1       0.47      0.03      0.05       868
#
#     accuracy                           0.94     13621
#    macro avg       0.70      0.51      0.51     13621
# weighted avg       0.91      0.94      0.91     13621
#
#  Test_auc_roc: 0.5127663103395569
#
# Epoch: 15, Loss:0.1736 Train:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     24555
#            1       0.81      0.71      0.76      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.84      0.86     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.844476385545055
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      4711
#            1       0.71      0.51      0.59       617
#
#     accuracy                           0.92      5328
#    macro avg       0.82      0.74      0.77      5328
# weighted avg       0.91      0.92      0.91      5328
#
#  Val_auc_roc: 0.739849182247693
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     12753
#            1       0.52      0.08      0.14       868
#
#     accuracy                           0.94     13621
#    macro avg       0.73      0.54      0.55     13621
# weighted avg       0.91      0.94      0.91     13621
#
#  Test_auc_roc: 0.538350197531908
#
# Epoch: 16, Loss:0.1694 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     24555
#            1       0.80      0.73      0.77      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.86      0.87     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8553446444755871
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4711
#            1       0.71      0.62      0.66       617
#
#     accuracy                           0.93      5328
#    macro avg       0.83      0.79      0.81      5328
# weighted avg       0.92      0.93      0.92      5328
#
#  Val_auc_roc: 0.7926195699777788
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     12753
#            1       0.48      0.11      0.18       868
#
#     accuracy                           0.94     13621
#    macro avg       0.71      0.55      0.57     13621
# weighted avg       0.91      0.94      0.92     13621
#
#  Test_auc_roc: 0.5517588976082614
#
# Epoch: 17, Loss:0.1668 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     24555
#            1       0.81      0.74      0.77      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.86      0.87     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8575701406606219
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4711
#            1       0.73      0.65      0.69       617
#
#     accuracy                           0.93      5328
#    macro avg       0.84      0.81      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8109784438434547
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     12753
#            1       0.60      0.19      0.28       868
#
#     accuracy                           0.94     13621
#    macro avg       0.77      0.59      0.63     13621
# weighted avg       0.92      0.94      0.93     13621
#
#  Test_auc_roc: 0.5885468441328163
#
# Epoch: 18, Loss:0.1618 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     24555
#            1       0.82      0.73      0.77      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.89      0.86      0.87     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8552179780484787
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4711
#            1       0.75      0.63      0.69       617
#
#     accuracy                           0.93      5328
#    macro avg       0.85      0.80      0.82      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8029521238440877
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     12753
#            1       0.68      0.21      0.32       868
#
#     accuracy                           0.94     13621
#    macro avg       0.82      0.60      0.64     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.6003932932018163
#
# Epoch: 19, Loss:0.1581 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     24555
#            1       0.84      0.72      0.78      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.90      0.85      0.87     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.852477930695797
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      4711
#            1       0.77      0.62      0.69       617
#
#     accuracy                           0.93      5328
#    macro avg       0.86      0.80      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.79978804047357
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     12753
#            1       0.73      0.21      0.32       868
#
#     accuracy                           0.94     13621
#    macro avg       0.84      0.60      0.65     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.6016358399089976
#
# Epoch: 20, Loss:0.1562 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     24555
#            1       0.84      0.72      0.78      3060
#
#     accuracy                           0.95     27615
#    macro avg       0.90      0.85      0.88     27615
# weighted avg       0.95      0.95      0.95     27615
#
#  Train_auc_roc: 0.8526194696978772
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      4711
#            1       0.78      0.63      0.70       617
#
#     accuracy                           0.94      5328
#    macro avg       0.87      0.80      0.83      5328
# weighted avg       0.93      0.94      0.93      5328
#
#  Val_auc_roc: 0.8038786081886354
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     12753
#            1       0.75      0.22      0.34       868
#
#     accuracy                           0.95     13621
#    macro avg       0.85      0.61      0.66     13621
# weighted avg       0.94      0.95      0.93     13621
#
#  Test_auc_roc: 0.6092811450165696
#
# Epoch: 21, Loss:0.1531 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     24555
#            1       0.85      0.73      0.78      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.86      0.88     27615
# weighted avg       0.95      0.96      0.95     27615
#
#  Train_auc_roc: 0.8559078060057255
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4711
#            1       0.78      0.66      0.72       617
#
#     accuracy                           0.94      5328
#    macro avg       0.87      0.82      0.84      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8190247178316757
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     12753
#            1       0.74      0.27      0.39       868
#
#     accuracy                           0.95     13621
#    macro avg       0.85      0.63      0.68     13621
# weighted avg       0.94      0.95      0.94     13621
#
#  Test_auc_roc: 0.6304648296361821
#
# Epoch: 22, Loss:0.1510 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24555
#            1       0.84      0.74      0.79      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.86      0.88     27615
# weighted avg       0.95      0.96      0.96     27615
#
#  Train_auc_roc: 0.8631187091004188
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4711
#            1       0.74      0.70      0.72       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.84      0.84      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8357815960232388
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     12753
#            1       0.67      0.31      0.43       868
#
#     accuracy                           0.95     13621
#    macro avg       0.81      0.65      0.70     13621
# weighted avg       0.94      0.95      0.94     13621
#
#  Test_auc_roc: 0.6503939074966006
#
# Epoch: 23, Loss:0.1474 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24555
#            1       0.84      0.75      0.79      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.87      0.89     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8662232842638175
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.72      0.71      0.72       617
#
#     accuracy                           0.94      5328
#    macro avg       0.84      0.84      0.84      5328
# weighted avg       0.93      0.94      0.93      5328
#
#  Val_auc_roc: 0.8393315138506484
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     12753
#            1       0.62      0.34      0.44       868
#
#     accuracy                           0.94     13621
#    macro avg       0.79      0.66      0.71     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.6639865798270652
#
# Epoch: 24, Loss:0.1465 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24555
#            1       0.85      0.75      0.80      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.91      0.87      0.89     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8676720128083814
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.71      0.73      0.72       617
#
#     accuracy                           0.93      5328
#    macro avg       0.84      0.84      0.84      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.844926715535591
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.59      0.35      0.44       868
#
#     accuracy                           0.94     13621
#    macro avg       0.77      0.67      0.71     13621
# weighted avg       0.93      0.94      0.94     13621
#
#  Test_auc_roc: 0.668911552752926
#
# Epoch: 25, Loss:0.1442 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     24555
#            1       0.86      0.75      0.80      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.92      0.87      0.89     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8697534745928508
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.70      0.73      0.71       617
#
#     accuracy                           0.93      5328
#    macro avg       0.83      0.85      0.84      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8460842189062668
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.56      0.35      0.43       868
#
#     accuracy                           0.94     13621
#    macro avg       0.76      0.67      0.70     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.666281693545677
#
# Epoch: 26, Loss:0.1410 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.87      0.75      0.81      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.92      0.87      0.89     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8687104978419794
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.69      0.73      0.71       617
#
#     accuracy                           0.93      5328
#    macro avg       0.83      0.84      0.84      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.843334696855905
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.54      0.35      0.42       868
#
#     accuracy                           0.94     13621
#    macro avg       0.75      0.66      0.70     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.6649607339160462
#
# Epoch: 27, Loss:0.1400 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.88      0.75      0.81      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.92      0.87      0.89     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8697713416460048
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.73      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8406526055264981
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.52      0.35      0.42       868
#
#     accuracy                           0.94     13621
#    macro avg       0.74      0.67      0.69     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.6656302700620547
#
# Epoch: 28, Loss:0.1386 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.88      0.76      0.81      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.93      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8714043304147152
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4711
#            1       0.67      0.73      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.842938885404586
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.49      0.36      0.42       868
#
#     accuracy                           0.94     13621
#    macro avg       0.72      0.67      0.69     13621
# weighted avg       0.93      0.94      0.93     13621
#
#  Test_auc_roc: 0.6681334761388031
#
# Epoch: 29, Loss:0.1378 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.88      0.75      0.81      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.93      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8707909614670547
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4711
#            1       0.67      0.74      0.71       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.85      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8481869564903273
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.48      0.36      0.42       868
#
#     accuracy                           0.93     13621
#    macro avg       0.72      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6688150723368242
#
# Epoch: 30, Loss:0.1359 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.89      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.93      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.871606956771713
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4711
#            1       0.68      0.74      0.71       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.85      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8486114948049102
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.48      0.37      0.42       868
#
#     accuracy                           0.93     13621
#    macro avg       0.72      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6693126962807342
#
# Epoch: 31, Loss:0.1335 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.90      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.93      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8713606110332548
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4711
#            1       0.68      0.73      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8440676619119981
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.48      0.36      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.72      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6670085488152964
#
# Epoch: 32, Loss:0.1311 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.90      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8712369390843284
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.72      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8382214872120735
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.48      0.36      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.72      0.66      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6649004336559827
#
# Epoch: 33, Loss:0.1315 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.91      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.870174098961515
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.72      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8391379945621941
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.47      0.36      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.72      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6656212363152286
#
# Epoch: 34, Loss:0.1292 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.90      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8713591137941635
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4711
#            1       0.67      0.73      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8411058707043448
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.47      0.37      0.42       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6728624167585399
#
# Epoch: 35, Loss:0.1282 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.90      0.76      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8740350793137455
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4711
#            1       0.66      0.75      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.81      0.85      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8477237143180535
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.38      0.42       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.68      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6759929262148854
#
# Epoch: 36, Loss:0.1277 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.90      0.76      0.83      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.88      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8750154714706082
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4711
#            1       0.66      0.75      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.81      0.85      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8477237143180535
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.39      0.42       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.68      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6796331196671535
#
# Epoch: 37, Loss:0.1264 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.91      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.871419202989687
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4711
#            1       0.67      0.74      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8447331962471364
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.38      0.42       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6746568802280551
#
# Epoch: 38, Loss:0.1258 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.91      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8694375571446253
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4711
#            1       0.68      0.72      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8394176944404402
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.37      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6686733328491244
#
# Epoch: 39, Loss:0.1244 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.92      0.75      0.82      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8698045803538276
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4711
#            1       0.67      0.72      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8370927107046615
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.36      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6675212591164056
#
# Epoch: 40, Loss:0.1239 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.92      0.75      0.83      3060
#
#     accuracy                           0.96     27615
#    macro avg       0.94      0.87      0.90     27615
# weighted avg       0.96      0.96      0.96     27615
#
#  Train_auc_roc: 0.8708867847688861
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.72      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8366007416691236
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.37      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6692885761767088
#
# Epoch: 41, Loss:0.1226 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.92      0.75      0.83      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.87      0.90     27615
# weighted avg       0.96      0.97      0.96     27615
#
#  Train_auc_roc: 0.870539125851929
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.71      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8352983998621111
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.36      0.40       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.68     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6659107679010017
#
# Epoch: 42, Loss:0.1218 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.93      0.75      0.83      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.87      0.90     27615
# weighted avg       0.96      0.97      0.96     27615
#
#  Train_auc_roc: 0.8702525542898895
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.71      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.8351922652834652
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     12753
#            1       0.46      0.36      0.41       868
#
#     accuracy                           0.93     13621
#    macro avg       0.71      0.67      0.69     13621
# weighted avg       0.93      0.93      0.93     13621
#
#  Test_auc_roc: 0.6666828370734851
#
# Epoch: 43, Loss:0.1215 Train:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24555
#            1       0.93      0.75      0.83      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.87      0.90     27615
# weighted avg       0.96      0.97      0.96     27615
#
#  Train_auc_roc: 0.8702729167415286
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4711
#            1       0.68      0.72      0.70       617
#
#     accuracy                           0.93      5328
#    macro avg       0.82      0.84      0.83      5328
# weighted avg       0.93      0.93      0.93      5328
#
#  Val_auc_roc: 0.836813010826415
#
# Test:
# ...
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7052471344051694
#
# Epoch: 106, Loss:0.0895 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.91      0.84      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.9166612766059388
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.78      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8690643333802368
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.55      0.44      0.49       868
#
#     accuracy                           0.94     13621
#    macro avg       0.76      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7078920799696177
#
# Epoch: 107, Loss:0.0916 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.91      0.84      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.9173148713771806
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.78      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8705789443445406
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.55      0.45      0.49       868
#
#     accuracy                           0.94     13621
#    macro avg       0.76      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7111130624004255
#
# Epoch: 108, Loss:0.0899 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.92      0.85      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.9176823936660798
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.78      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8690643333802368
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12753
#            1       0.55      0.44      0.49       868
#
#     accuracy                           0.94     13621
#    macro avg       0.76      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7100001951289314
#
# Epoch: 109, Loss:0.0897 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.92      0.84      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.917600444779826
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.77      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8683600951874075
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.55      0.45      0.49       868
#
#     accuracy                           0.94     13621
#    macro avg       0.76      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7103801996891668
#
# Epoch: 110, Loss:0.0902 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.92      0.84      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.9168445386706914
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.77      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8681478260301161
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.55      0.45      0.49       868
#
#     accuracy                           0.94     13621
#    macro avg       0.75      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7108386171718517
#
# Epoch: 111, Loss:0.0899 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.92      0.85      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.9180702784066183
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.78      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8696624369944201
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.55      0.46      0.50       868
#
#     accuracy                           0.94     13621
#    macro avg       0.75      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7146748429302439
#
# Epoch: 112, Loss:0.0889 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.92      0.85      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.9185604744850496
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.78      0.75       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8698747061517115
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.55      0.45      0.49       868
#
#     accuracy                           0.94     13621
#    macro avg       0.75      0.71      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7103017867667172
#
# Epoch: 113, Loss:0.0887 Train:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24555
#            1       0.91      0.85      0.88      3060
#
#     accuracy                           0.97     27615
#    macro avg       0.95      0.92      0.93     27615
# weighted avg       0.97      0.97      0.97     27615
#
#  Train_auc_roc: 0.920726380554258
#
# Valid:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4711
#            1       0.73      0.79      0.76       617
#
#     accuracy                           0.94      5328
#    macro avg       0.85      0.87      0.86      5328
# weighted avg       0.94      0.94      0.94      5328
#
#  Val_auc_roc: 0.8743124044659779
#
# Test:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12753
#            1       0.55      0.46      0.50       868
#
#     accuracy                           0.94     13621
#    macro avg       0.76      0.72      0.73     13621
# weighted avg       0.94      0.94      0.94     13621
#
#  Test_auc_roc: 0.7154861185639522
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 15
#      13 loss = train_ind(model, data2['train'], optimizer, loss_fn)
#      14 losses.append(loss)
# ---> 15 result = test_ind(model, data2)
#      16 train_acc, val_acc, test_acc, train_auc, val_auc, test_auc = result
#      17 if val_auc > best_valid_auc:
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[27], line 25, in test_ind(model, data, save_model_results)
#      20 train_acc = classification_report(torch.unsqueeze(data['train'].y, -1),
#      21                                   train_pred, zero_division=0)
#      22 train_auc_roc = roc_auc_score(torch.unsqueeze(data['train'].y, -1),
#      23                               train_pred)
# ---> 25 val_out = model.forward(data['val'].x, data['val'].edge_index)
#      26 val_pred = val_out.argmax(dim=-1, keepdim=True)
#      27 val_acc = classification_report(torch.unsqueeze(data['val'].y, -1),
#      28                                 val_pred, zero_division=0)
#
# Cell In[21], line 64, in GCN.forward(self, x, edge_index)
#      61 x = torch.clone(x.detach())
#      62 for l in range(self.num_layers - 1):
#      63     # Unweighted graph has weight 1.
# ---> 64     x = self.convs[l](x, edge_index, torch.ones(edge_index.shape[1]))
#      65     x = self.bns[l](x)
#      66     x = F.relu(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[22], line 72, in GCNLayer.forward(self, x, edge_index, edge_weight)
#      69     deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
#      70     norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]
# ---> 72 return self.propagate(edge_index, x = (x, x), norm = norm, edge_weight = edge_weight)
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:572, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     569     if res is not None:
#     570         aggr_kwargs = res[0] if isinstance(res, tuple) else res
# --> 572 out = self.aggregate(out, **aggr_kwargs)
#     574 for hook in self._aggregate_forward_hooks.values():
#     575     res = hook(self, (aggr_kwargs, ), out)
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:625, in MessagePassing.aggregate(self, inputs, index, ptr, dim_size)
#     608 def aggregate(
#     609     self,
#     610     inputs: Tensor,
#    (...)
#     613     dim_size: Optional[int] = None,
#     614 ) -> Tensor:
#     615     r"""Aggregates messages from neighbors as
#     616     :math:`\bigoplus_{j \in \mathcal{N}(i)}`.
#     617
#    (...)
#     623     as specified in :meth:`__init__` by the :obj:`aggr` argument.
#     624     """
# --> 625     return self.aggr_module(inputs, index, ptr=ptr, dim_size=dim_size,
#     626                             dim=self.node_dim)
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/experimental.py:117, in disable_dynamic_shapes.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     114 @functools.wraps(func)
#     115 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     116     if not is_experimental_mode_enabled('disable_dynamic_shapes'):
# --> 117         return func(*args, **kwargs)
#     119     for required_arg in required_args:
#     120         index = required_args_pos[required_arg]
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/nn/aggr/base.py:128, in Aggregation.__call__(self, x, index, ptr, dim_size, dim, **kwargs)
#     125     dim_size = int(index.max()) + 1 if index.numel() > 0 else 0
#     127 try:
# --> 128     return super().__call__(x, index=index, ptr=ptr, dim_size=dim_size,
#     129                             dim=dim, **kwargs)
#     130 except (IndexError, RuntimeError) as e:
#     131     if index is not None:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/nn/aggr/basic.py:22, in SumAggregation.forward(self, x, index, ptr, dim_size, dim)
#      19 def forward(self, x: Tensor, index: Optional[Tensor] = None,
#      20             ptr: Optional[Tensor] = None, dim_size: Optional[int] = None,
#      21             dim: int = -2) -> Tensor:
# ---> 22     return self.reduce(x, index, ptr, dim_size, dim, reduce='sum')
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/nn/aggr/base.py:182, in Aggregation.reduce(self, x, index, ptr, dim_size, dim, reduce)
#     179 if index is None:
#     180     raise NotImplementedError(
#     181         "Aggregation requires 'index' to be specified")
# --> 182 return scatter(x, index, dim, dim_size, reduce)
#
# File ~/.local/lib/python3.10/site-packages/torch_geometric/utils/_scatter.py:75, in scatter(src, index, dim, dim_size, reduce)
#      73 if reduce == 'sum' or reduce == 'add':
#      74     index = broadcast(index, src, dim)
# ---> 75     return src.new_zeros(size).scatter_add_(dim, index, src)
#      77 if reduce == 'mean':
#      78     count = src.new_zeros(dim_size)
#
# KeyboardInterrupt:

# %% [markdown]
# # Temporal step split - inductive

# %%
model = GCN(data['train'][0].x.shape[1], args['hidden_dim'],
            2, args['num_layers'], args['dropout']).to(device)

# %%
model.reset_parameters()

optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
loss_fn = torch.nn.NLLLoss(weight=args['label_weight'])

best_model = None
best_valid_auc = 0
best_result = None
losses = []

for epoch in range(1, 1 + args["epochs"]):
    # train with random split
    loss = train_ind_time_step(model, data['train'], optimizer, loss_fn)
    losses.append(loss)
    result = test_ind_time_step(model, data)
    train_acc, val_acc, test_acc, train_auc, val_auc, test_auc = result
    if val_auc > best_valid_auc:
        best_valid_auc = val_auc
        best_model = copy.deepcopy(model)
        best_result = [train_acc, val_acc, test_acc, train_auc, val_auc, test_auc]

    print('Epoch: {:02},'.format(epoch),
          'Loss:{:.4f}'.format(loss),
          'Train:\n{}\n'.format(train_acc),
          'Train_auc_roc: {}'.format(train_auc),
          '\n\n'
          'Valid:\n{}\n'.format(val_acc),
          'Val_auc_roc: {}'.format(val_auc),
          '\n\n'
          'Test:\n{}\n'.format(test_acc),
          'Test_auc_roc: {}'.format(test_auc),
          '\n'
          )
# Out:
# Epoch: 01, Loss:0.6006 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.919193   0.393808  0.864049    0.656501      0.878676
# recall       0.921601   0.369237  0.864049    0.645419      0.864049
# f1-score     0.915372   0.304793  0.864049    0.610082      0.852730
# support    792.096774  98.709677  0.864049  890.806452    890.806452
#  Train_auc_roc: 0.6454188643898955
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.954673    0.235184  0.738035     0.594929      0.888828
# recall       0.723128    0.806928  0.738035     0.765028      0.738035
# f1-score     0.820512    0.351984  0.738035     0.586248      0.785019
# support    942.200000  123.400000  0.738035  1065.600000   1065.600000
#  Val_auc_roc: 0.7650280403991789
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.969634   0.194853  0.831384     0.582244      0.925189
# recall       0.848146   0.459397  0.831384     0.653772      0.831384
# f1-score     0.900593   0.251816  0.831384     0.576205      0.865424
# support    981.000000  66.769231  0.831384  1047.769231   1047.769231
#  Test_auc_roc: 0.6537715584301143
#
# Epoch: 02, Loss:0.3786 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.885944   0.195369  0.879631    0.540656      0.811550
# recall       0.988780   0.114018  0.879631    0.551399      0.879631
# f1-score     0.931420   0.128094  0.879631    0.529757      0.837210
# support    792.096774  98.709677  0.879631  890.806452    890.806452
#  Train_auc_roc: 0.5513991508332288
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.930907    0.547508  0.915142     0.739208      0.906455
# recall       0.971315    0.334463  0.915142     0.652889      0.915142
# f1-score     0.950444    0.408927  0.915142     0.679685      0.907159
# support    942.200000  123.400000  0.915142  1065.600000   1065.600000
#  Val_auc_roc: 0.6528889660702938
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 03, Loss:0.2616 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.865752   0.000000  0.865752    0.432876      0.760043
# recall       1.000000   0.000000  0.865752    0.500000      0.865752
# f1-score     0.924696   0.000000  0.865752    0.462348      0.806809
# support    792.096774  98.709677  0.865752  890.806452    890.806452
#  Train_auc_roc: 0.5
#
# Valid:
#                     0      1  accuracy    macro avg  weighted avg
# precision    0.892491    0.0  0.892491     0.446246      0.803683
# recall       1.000000    0.0  0.892491     0.500000      0.892491
# f1-score     0.940994    0.0  0.892491     0.470497      0.843989
# support    942.200000  123.4  0.892491  1065.600000   1065.600000
#  Val_auc_roc: 0.5
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 04, Loss:0.3106 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.865752   0.000000  0.865752    0.432876      0.760043
# recall       1.000000   0.000000  0.865752    0.500000      0.865752
# f1-score     0.924696   0.000000  0.865752    0.462348      0.806809
# support    792.096774  98.709677  0.865752  890.806452    890.806452
#  Train_auc_roc: 0.5
#
# Valid:
#                     0      1  accuracy    macro avg  weighted avg
# precision    0.892491    0.0  0.892491     0.446246      0.803683
# recall       1.000000    0.0  0.892491     0.500000      0.892491
# f1-score     0.940994    0.0  0.892491     0.470497      0.843989
# support    942.200000  123.4  0.892491  1065.600000   1065.600000
#  Val_auc_roc: 0.5
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 05, Loss:0.3063 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.865752   0.000000  0.865752    0.432876      0.760043
# recall       1.000000   0.000000  0.865752    0.500000      0.865752
# f1-score     0.924696   0.000000  0.865752    0.462348      0.806809
# support    792.096774  98.709677  0.865752  890.806452    890.806452
#  Train_auc_roc: 0.5
#
# Valid:
#                     0      1  accuracy    macro avg  weighted avg
# precision    0.892491    0.0  0.892491     0.446246      0.803683
# recall       1.000000    0.0  0.892491     0.500000      0.892491
# f1-score     0.940994    0.0  0.892491     0.470497      0.843989
# support    942.200000  123.4  0.892491  1065.600000   1065.600000
#  Val_auc_roc: 0.5
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 06, Loss:0.2766 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.865752   0.000000  0.865752    0.432876      0.760043
# recall       1.000000   0.000000  0.865752    0.500000      0.865752
# f1-score     0.924696   0.000000  0.865752    0.462348      0.806809
# support    792.096774  98.709677  0.865752  890.806452    890.806452
#  Train_auc_roc: 0.5
#
# Valid:
#                     0      1  accuracy    macro avg  weighted avg
# precision    0.892491    0.0  0.892491     0.446246      0.803683
# recall       1.000000    0.0  0.892491     0.500000      0.892491
# f1-score     0.940994    0.0  0.892491     0.470497      0.843989
# support    942.200000  123.4  0.892491  1065.600000   1065.600000
#  Val_auc_roc: 0.5
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 07, Loss:0.2573 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.866621   0.311828  0.866778    0.589224      0.819905
# recall       0.999940   0.006559  0.866778    0.503249      0.866778
# f1-score     0.925198   0.012739  0.866778    0.468969      0.809308
# support    792.096774  98.709677  0.866778  890.806452    890.806452
#  Train_auc_roc: 0.5032494817188865
#
# Valid:
#                     0      1  accuracy    macro avg  weighted avg
# precision    0.892491    0.0  0.892491     0.446246      0.803683
# recall       1.000000    0.0  0.892491     0.500000      0.892491
# f1-score     0.940994    0.0  0.892491     0.470497      0.843989
# support    942.200000  123.4  0.892491  1065.600000   1065.600000
#  Val_auc_roc: 0.5
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 08, Loss:0.2461 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.894622   0.644378  0.893323    0.769500      0.895433
# recall       0.992161   0.197191  0.893323    0.594676      0.893323
# f1-score     0.938446   0.260123  0.893323    0.599285      0.862874
# support    792.096774  98.709677  0.893323  890.806452    890.806452
#  Train_auc_roc: 0.5946760317345468
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.892604    0.200000  0.892643     0.546302      0.855467
# recall       1.000000    0.000585  0.892643     0.500292      0.892643
# f1-score     0.941068    0.001166  0.892643     0.471117      0.844345
# support    942.200000  123.400000  0.892643  1065.600000   1065.600000
#  Val_auc_roc: 0.5002923976608187
#
# Test:
#                    0          1  accuracy    macro avg  weighted avg
# precision    0.93376   0.000000   0.93376     0.466880      0.874056
# recall       1.00000   0.000000   0.93376     0.500000      0.933760
# f1-score     0.96515   0.000000   0.93376     0.482575      0.902369
# support    981.00000  66.769231   0.93376  1047.769231   1047.769231
#  Test_auc_roc: 0.5
#
# Epoch: 09, Loss:0.2414 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.944616   0.611813  0.926713    0.778215      0.926198
# recall       0.970059   0.490229  0.926713    0.730144      0.926713
# f1-score     0.955999   0.508596  0.926713    0.732297      0.919536
# support    792.096774  98.709677  0.926713  890.806452    890.806452
#  Train_auc_roc: 0.7301439625042232
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.897140    0.536842  0.894056     0.716991      0.878851
# recall       0.994391    0.054300  0.894056     0.524345      0.894056
# f1-score     0.941361    0.089706  0.894056     0.515533      0.855260
# support    942.200000  123.400000  0.894056  1065.600000   1065.600000
#  Val_auc_roc: 0.5243454928881838
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.933902   0.076923  0.933914     0.505413      0.880366
# recall       1.000000   0.001923  0.933914     0.500962      0.933914
# f1-score     0.965227   0.003752  0.933914     0.484490      0.902742
# support    981.000000  66.769231  0.933914  1047.769231   1047.769231
#  Test_auc_roc: 0.5009615384615385
#
# Epoch: 10, Loss:0.2404 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.954952   0.577805  0.925584    0.766379      0.928449
# recall       0.955745   0.560404  0.925584    0.758074      0.925584
# f1-score     0.954374   0.542994  0.925584    0.748684      0.923083
# support    792.096774  98.709677  0.925584  890.806452    890.806452
#  Train_auc_roc: 0.7580744669586529
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.923422    0.570845  0.913907     0.747133      0.907953
# recall       0.981325    0.258003  0.913907     0.619664      0.913907
# f1-score     0.950839    0.325372  0.913907     0.638105      0.898237
# support    942.200000  123.400000  0.913907  1065.600000   1065.600000
#  Val_auc_roc: 0.6196639373048168
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935463   0.384615  0.935628     0.660039      0.913337
# recall       1.000000   0.020834  0.935628     0.510417      0.935628
# f1-score     0.966085   0.038753  0.935628     0.502419      0.906696
# support    981.000000  66.769231  0.935628  1047.769231   1047.769231
#  Test_auc_roc: 0.5104172403741369
#
# Epoch: 11, Loss:0.2400 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.955279   0.567397  0.923179    0.761338      0.927042
# recall       0.952221   0.564992  0.923179    0.758606      0.923179
# f1-score     0.952755   0.540440  0.923179    0.746597      0.921227
# support    792.096774  98.709677  0.923179  890.806452    890.806452
#  Train_auc_roc: 0.7586064165858002
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.933204    0.613662  0.920683     0.773433      0.916591
# recall       0.976157    0.359171  0.920683     0.667664      0.920683
# f1-score     0.953831    0.437758  0.920683     0.695795      0.912405
# support    942.200000  123.400000  0.920683  1065.600000   1065.600000
#  Val_auc_roc: 0.6676642920113529
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936649   0.364011  0.936742     0.650330      0.912849
# recall       0.999762   0.033748  0.936742     0.516755      0.936742
# f1-score     0.966636   0.060519  0.936742     0.513577      0.909474
# support    981.000000  66.769231  0.936742  1047.769231   1047.769231
#  Test_auc_roc: 0.5167551910837078
#
# Epoch: 12, Loss:0.2307 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.951554   0.590719  0.926738    0.771136      0.928380
# recall       0.961334   0.535549  0.926738    0.748442      0.926738
# f1-score     0.955395   0.531349  0.926738    0.743372      0.922706
# support    792.096774  98.709677  0.926738  890.806452    890.806452
#  Train_auc_roc: 0.7484415146411628
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.934356    0.624270  0.922547     0.779313      0.918894
# recall       0.977265    0.366916  0.922547     0.672090      0.922547
# f1-score     0.954958    0.446252  0.922547     0.700605      0.914419
# support    942.200000  123.400000  0.922547  1065.600000   1065.600000
#  Val_auc_roc: 0.6720903153235688
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937316   0.373626  0.937646     0.655471      0.914202
# recall       0.999930   0.038342  0.937646     0.519136      0.937646
# f1-score     0.967098   0.068375  0.937646     0.517737      0.911123
# support    981.000000  66.769231  0.937646  1047.769231   1047.769231
#  Test_auc_roc: 0.5191363372057565
#
# Epoch: 13, Loss:0.2237 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.942787   0.636859  0.927984    0.789823      0.928504
# recall       0.973826   0.481495  0.927984    0.727661      0.927984
# f1-score     0.956794   0.507171  0.927984    0.731982      0.919913
# support    792.096774  98.709677  0.927984  890.806452    890.806452
#  Train_auc_roc: 0.7276606848274346
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.927216    0.685517   0.92153     0.806367      0.920131
# recall       0.986343    0.291215   0.92153     0.638779      0.921530
# f1-score     0.955258    0.384667   0.92153     0.669962      0.907976
# support    942.200000  123.400000   0.92153  1065.600000   1065.600000
#  Val_auc_roc: 0.6387788295687541
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937171   0.384615  0.937545     0.660893      0.914829
# recall       1.000000   0.036963  0.937545     0.518481      0.937545
# f1-score     0.967050   0.066114  0.937545     0.516582      0.910813
# support    981.000000  66.769231  0.937545  1047.769231   1047.769231
#  Test_auc_roc: 0.5184813318434008
#
# Epoch: 14, Loss:0.2161 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.930410   0.688099  0.925264    0.809255      0.926243
# recall       0.985672   0.411182  0.925264    0.698427      0.925264
# f1-score     0.955797   0.474575  0.925264    0.715186      0.912810
# support    792.096774  98.709677  0.925264  890.806452    890.806452
#  Train_auc_roc: 0.6984271546533372
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.914534    0.741536  0.913036     0.828035      0.912416
# recall       0.993026    0.180958  0.913036     0.586992      0.913036
# f1-score     0.951160    0.262863  0.913036     0.607012      0.889864
# support    942.200000  123.400000  0.913036  1065.600000   1065.600000
#  Val_auc_roc: 0.5869918499890158
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937023   0.384615   0.93738     0.660819      0.914699
# recall       1.000000   0.035583   0.93738     0.517791      0.937380
# f1-score     0.966966   0.063692   0.93738     0.515329      0.910457
# support    981.000000  66.769231   0.93738  1047.769231   1047.769231
#  Test_auc_roc: 0.5177914249034938
#
# Epoch: 15, Loss:0.2139 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.918963   0.725340  0.918441    0.822152      0.922204
# recall       0.992062   0.344600  0.918441    0.668331      0.918441
# f1-score     0.952255   0.426328  0.918441    0.689291      0.900901
# support    792.096774  98.709677  0.918441  890.806452    890.806452
#  Train_auc_roc: 0.6683310018122268
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.903719    0.596422  0.902735     0.750071      0.887356
# recall       0.995663    0.089240  0.902735     0.542451      0.902735
# f1-score     0.945983    0.137501  0.902735     0.541742      0.870038
# support    942.200000  123.400000  0.902735  1065.600000   1065.600000
#  Val_auc_roc: 0.5424512540596822
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936707   0.384615   0.93704     0.660661      0.914411
# recall       1.000000   0.031420   0.93704     0.515710      0.937040
# f1-score     0.966795   0.056989   0.93704     0.511892      0.909756
# support    981.000000  66.769231   0.93704  1047.769231   1047.769231
#  Test_auc_roc: 0.5157101437992242
#
# Epoch: 16, Loss:0.2104 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.915907   0.734706  0.917103    0.825307      0.921355
# recall       0.993893   0.328259  0.917103    0.661076      0.917103
# f1-score     0.951515   0.419669  0.917103    0.685592      0.898946
# support    792.096774  98.709677  0.917103  890.806452    890.806452
#  Train_auc_roc: 0.6610761080853612
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.902890    0.605333  0.902282     0.754112      0.887548
# recall       0.996345    0.085146  0.902282     0.540746      0.902282
# f1-score     0.945773    0.133639  0.902282     0.539706      0.868640
# support    942.200000  123.400000  0.902282  1065.600000   1065.600000
#  Val_auc_roc: 0.5407456416828965
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936848   0.371795   0.93713     0.654321      0.913662
# recall       0.999930   0.033343   0.93713     0.516637      0.937130
# f1-score     0.966838   0.059994   0.93713     0.513416      0.910038
# support    981.000000  66.769231   0.93713  1047.769231   1047.769231
#  Test_auc_roc: 0.5166367806832114
#
# Epoch: 17, Loss:0.2052 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.924953   0.726800  0.925452    0.825877      0.926875
# recall       0.992429   0.375844  0.925452    0.684137      0.925452
# f1-score     0.956110   0.461922  0.925452    0.709016      0.910944
# support    792.096774  98.709677  0.925452  890.806452    890.806452
#  Train_auc_roc: 0.6841365041455089
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.907914    0.645924  0.908135     0.776919      0.897180
# recall       0.996345    0.115486  0.908135     0.555915      0.908135
# f1-score     0.948848    0.178054  0.908135     0.563451      0.878771
# support    942.200000  123.400000  0.908135  1065.600000   1065.600000
#  Val_auc_roc: 0.555915267378838
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936905   0.371795  0.937193     0.654350      0.913715
# recall       0.999930   0.034030  0.937193     0.516980      0.937193
# f1-score     0.966870   0.061332  0.937193     0.514101      0.910191
# support    981.000000  66.769231  0.937193  1047.769231   1047.769231
#  Test_auc_roc: 0.516980187276618
#
# Epoch: 18, Loss:0.1990 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.936366   0.709073  0.934739    0.822720      0.933553
# recall       0.989445   0.441562  0.934739    0.715504      0.934739
# f1-score     0.961214   0.520807  0.934739    0.741010      0.925170
# support    792.096774  98.709677  0.934739  890.806452    890.806452
#  Train_auc_roc: 0.7155037661096278
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.914456    0.808516  0.915228     0.861486      0.918888
# recall       0.996226    0.175577  0.915228     0.585901      0.915228
# f1-score     0.952537    0.270292  0.915228     0.611414      0.892180
# support    942.200000  123.400000  0.915228  1065.600000   1065.600000
#  Val_auc_roc: 0.5859012124079198
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937021   0.371795   0.93732     0.654408      0.913820
# recall       0.999930   0.035404   0.93732     0.517667      0.937320
# f1-score     0.966933   0.063938   0.93732     0.515436      0.910489
# support    981.000000  66.769231   0.93732  1047.769231   1047.769231
#  Test_auc_roc: 0.5176670004634312
#
# Epoch: 19, Loss:0.1947 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.947482   0.697265  0.941295    0.822373      0.939108
# recall       0.984115   0.531081  0.941295    0.757598      0.941295
# f1-score     0.964788   0.586867  0.941295    0.775828      0.935467
# support    792.096774  98.709677  0.941295  890.806452    890.806452
#  Train_auc_roc: 0.7575979210125933
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.920720    0.824142  0.920899     0.872431      0.923906
# recall       0.994861    0.227999  0.920899     0.611430      0.920899
# f1-score     0.955518    0.340035  0.920899     0.647777      0.902727
# support    942.200000  123.400000  0.920899  1065.600000   1065.600000
#  Val_auc_roc: 0.6114300777001845
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937066   0.366300  0.937282     0.651683      0.913054
# recall       0.999811   0.036091  0.937282     0.517951      0.937282
# f1-score     0.966906   0.065078  0.937282     0.515992      0.910566
# support    981.000000  66.769231  0.937282  1047.769231   1047.769231
#  Test_auc_roc: 0.5179507767646493
#
# Epoch: 20, Loss:0.1909 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.956592   0.687461  0.943389    0.822027      0.942160
# recall       0.976506   0.602812  0.943389    0.789659      0.943389
# f1-score     0.965930   0.625672  0.943389    0.795801      0.939928
# support    792.096774  98.709677  0.943389  890.806452    890.806452
#  Train_auc_roc: 0.7896591864405632
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.925721    0.815887  0.925196     0.870804      0.926852
# recall       0.993363    0.271971  0.925196     0.632667      0.925196
# f1-score     0.957647    0.393981  0.925196     0.675814      0.911024
# support    942.200000  123.400000  0.925196  1065.600000   1065.600000
#  Val_auc_roc: 0.6326669101876206
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937266   0.363004  0.937434     0.650135      0.912839
# recall       0.999735   0.038963  0.937434     0.519349      0.937434
# f1-score     0.966979   0.069573  0.937434     0.518276      0.910973
# support    981.000000  66.769231  0.937434  1047.769231   1047.769231
#  Test_auc_roc: 0.5193492931894125
#
# Epoch: 21, Loss:0.1898 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.959939   0.656063  0.940492    0.808001      0.941050
# recall       0.969190   0.628516  0.940492    0.798853      0.940492
# f1-score     0.964002   0.623072  0.940492    0.793537      0.938127
# support    792.096774  98.709677  0.940492  890.806452    890.806452
#  Train_auc_roc: 0.7988527564834933
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.927349    0.816372  0.926941     0.871861      0.927580
# recall       0.993261    0.284182  0.926941     0.638721      0.926941
# f1-score     0.958544    0.408299  0.926941     0.683421      0.913522
# support    942.200000  123.400000  0.926941  1065.600000   1065.600000
#  Val_auc_roc: 0.638721430078016
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937558   0.363004  0.937743     0.650281      0.913108
# recall       0.999735   0.042810  0.937743     0.521272      0.937743
# f1-score     0.967135   0.075147  0.937743     0.521141      0.911564
# support    981.000000  66.769231  0.937743  1047.769231   1047.769231
#  Test_auc_roc: 0.5212723701124895
#
# Epoch: 22, Loss:0.1868 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.960526   0.632792   0.93762    0.796659      0.939686
# recall       0.965084   0.636432   0.93762    0.800758      0.937620
# f1-score     0.962198   0.615511   0.93762    0.788854      0.935866
# support    792.096774  98.709677   0.93762  890.806452    890.806452
#  Train_auc_roc: 0.800758347117595
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.926812    0.821641  0.927006     0.874226      0.928474
# recall       0.994281    0.277607  0.927006     0.635944      0.927006
# f1-score     0.958685    0.401928  0.927006     0.680306      0.913167
# support    942.200000  123.400000  0.927006  1065.600000   1065.600000
#  Val_auc_roc: 0.6359436160495984
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937412   0.363004  0.937588     0.650208      0.912973
# recall       0.999735   0.040886  0.937588     0.520311      0.937588
# f1-score     0.967057   0.072419  0.937588     0.519738      0.911273
# support    981.000000  66.769231  0.937588  1047.769231   1047.769231
#  Test_auc_roc: 0.5203108316509509
#
# Epoch: 23, Loss:0.1816 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.959532   0.636579   0.93754    0.798056      0.939670
# recall       0.966107   0.633274   0.93754    0.799691      0.937540
# f1-score     0.962185   0.614435   0.93754    0.788310      0.935621
# support    792.096774  98.709677   0.93754  890.806452    890.806452
#  Train_auc_roc: 0.7996905905455012
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.923204    0.820167  0.923318     0.871686      0.925392
# recall       0.994484    0.252068  0.923318     0.623276      0.923318
# f1-score     0.956734    0.372071  0.923318     0.664402      0.907314
# support    942.200000  123.400000  0.923318  1065.600000   1065.600000
#  Val_auc_roc: 0.6232760163950359
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937121   0.363004  0.937279     0.650062      0.912706
# recall       0.999735   0.037040  0.937279     0.518388      0.937279
# f1-score     0.966901   0.066600  0.937279     0.516750      0.910662
# support    981.000000  66.769231  0.937279  1047.769231   1047.769231
#  Test_auc_roc: 0.5183877547278741
#
# Epoch: 24, Loss:0.1792 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.958052   0.642046  0.938213    0.800049      0.940215
# recall       0.968790   0.625022  0.938213    0.796906      0.938213
# f1-score     0.962734   0.609865  0.938213    0.786300      0.935802
# support    792.096774  98.709677  0.938213  890.806452    890.806452
#  Train_auc_roc: 0.7969062678513219
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.918890    0.823023   0.91894     0.870957      0.922295
# recall       0.994861    0.218855   0.91894     0.606858      0.918940
# f1-score     0.954447    0.329460   0.91894     0.641954      0.899774
# support    942.200000  123.400000   0.91894  1065.600000   1065.600000
#  Val_auc_roc: 0.6068577494436457
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.937121   0.363004  0.937279     0.650062      0.912706
# recall       0.999735   0.037040  0.937279     0.518388      0.937279
# f1-score     0.966901   0.066600  0.937279     0.516750      0.910662
# support    981.000000  66.769231  0.937279  1047.769231   1047.769231
#  Test_auc_roc: 0.5183877547278741
#
# Epoch: 25, Loss:0.1766 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.956526   0.650449  0.938721    0.803488      0.940671
# recall       0.971481   0.615428  0.938721    0.793455      0.938721
# f1-score     0.963228   0.606615  0.938721    0.784922      0.935665
# support    792.096774  98.709677  0.938721  890.806452    890.806452
#  Train_auc_roc: 0.7934548830802426
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.913546    0.810417  0.913841     0.861981      0.918798
# recall       0.995716    0.165209  0.913841     0.580463      0.913841
# f1-score     0.951790    0.252708  0.913841     0.602249      0.890155
# support    942.200000  123.400000  0.913841  1065.600000   1065.600000
#  Val_auc_roc: 0.580462625146977
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 26, Loss:0.1754 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.955853   0.656630  0.938889    0.806242      0.940841
# recall       0.972716   0.615270  0.938889    0.793993      0.938889
# f1-score     0.963438   0.605879  0.938889    0.784658      0.935316
# support    792.096774  98.709677  0.938889  890.806452    890.806452
#  Train_auc_roc: 0.7939929642749911
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.911613    0.811789  0.911806     0.861701      0.917522
# recall       0.995920    0.148674  0.911806     0.572297      0.911806
# f1-score     0.950767    0.225902  0.911806     0.588334      0.885970
# support    942.200000  123.400000  0.911806  1065.600000   1065.600000
#  Val_auc_roc: 0.5722966642045796
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 27, Loss:0.1717 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.956015   0.650707  0.937498    0.803361      0.940326
# recall       0.970938   0.619164  0.937498    0.795051      0.937498
# f1-score     0.962577   0.602844  0.937498    0.782711      0.934046
# support    792.096774  98.709677  0.937498  890.806452    890.806452
#  Train_auc_roc: 0.7950508398971271
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.910409    0.811538  0.910451     0.860974      0.916517
# recall       0.995920    0.141868  0.910451     0.568894      0.910451
# f1-score     0.950050    0.216066  0.910451     0.583058      0.883600
# support    942.200000  123.400000  0.910451  1065.600000   1065.600000
#  Val_auc_roc: 0.5688939265913157
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 28, Loss:0.1715 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.957818   0.639721   0.93568    0.798769      0.940428
# recall       0.966818   0.633580   0.93568    0.800199      0.935680
# f1-score     0.961393   0.602027   0.93568    0.781710      0.933191
# support    792.096774  98.709677   0.93568  890.806452    890.806452
#  Train_auc_roc: 0.8001991498453043
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.911075    0.811667  0.911203     0.861371      0.917076
# recall       0.995920    0.145820  0.911203     0.570870      0.911203
# f1-score     0.950445    0.222010  0.911203     0.586228      0.884958
# support    942.200000  123.400000  0.911203  1065.600000   1065.600000
#  Val_auc_roc: 0.5708700206726729
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 29, Loss:0.1673 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.959321   0.629484  0.933593    0.794402      0.940463
# recall       0.962761   0.645443  0.933593    0.804102      0.933593
# f1-score     0.960087   0.601331  0.933593    0.780709      0.932244
# support    792.096774  98.709677  0.933593  890.806452    890.806452
#  Train_auc_roc: 0.804101947341221
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.913010    0.838571  0.913329     0.875791      0.919274
# recall       0.995920    0.171251  0.913329     0.583586      0.913329
# f1-score     0.951551    0.262948  0.913329     0.607249      0.888985
# support    942.200000  123.400000  0.913329  1065.600000   1065.600000
#  Val_auc_roc: 0.5835855175986961
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 30, Loss:0.1659 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.960781   0.620057  0.931676    0.790419      0.940337
# recall       0.958907   0.663094  0.931676    0.811000      0.931676
# f1-score     0.958828   0.600879  0.931676    0.779853      0.931184
# support    792.096774  98.709677  0.931676  890.806452    890.806452
#  Train_auc_roc: 0.8110003938633774
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.913401    0.825349  0.913634     0.869375      0.917781
# recall       0.995747    0.173006  0.913634     0.584376      0.913634
# f1-score     0.951712    0.264681  0.913634     0.608197      0.889560
# support    942.200000  123.400000  0.913634  1065.600000   1065.600000
#  Val_auc_roc: 0.5843764293041894
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 31, Loss:0.1634 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.961601   0.613882  0.930099    0.787741      0.940299
# recall       0.956299   0.671145  0.930099    0.813722      0.930099
# f1-score     0.957873   0.599847  0.930099    0.778860      0.930258
# support    792.096774  98.709677  0.930099  890.806452    890.806452
#  Train_auc_roc: 0.8137220760197545
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.913676    0.825420  0.913936     0.869548      0.918003
# recall       0.995747    0.174175  0.913936     0.584961      0.913936
# f1-score     0.951878    0.265920  0.913936     0.608899      0.890003
# support    942.200000  123.400000  0.913936  1065.600000   1065.600000
#  Val_auc_roc: 0.5849612246258268
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936988   0.356410  0.937049     0.646699      0.911760
# recall       0.999616   0.035404  0.937049     0.517510      0.937049
# f1-score     0.966777   0.063555  0.937049     0.515166      0.910303
# support    981.000000  66.769231  0.937049  1047.769231   1047.769231
#  Test_auc_roc: 0.5175098840341119
#
# Epoch: 32, Loss:0.1595 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.961884   0.615408  0.930128    0.788646      0.940790
# recall       0.956032   0.671907  0.930128    0.813969      0.930128
# f1-score     0.957869   0.601024  0.930128    0.779447      0.930435
# support    792.096774  98.709677  0.930128  890.806452    890.806452
#  Train_auc_roc: 0.8139694209064424
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.913269    0.824396  0.913485     0.868833      0.917538
# recall       0.995747    0.171907  0.913485     0.583827      0.913485
# f1-score     0.951637    0.262785  0.913485     0.607211      0.889238
# support    942.200000  123.400000  0.913485  1065.600000   1065.600000
#  Val_auc_roc: 0.5838269787547389
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936636   0.356044  0.936672     0.646340      0.911400
# recall       0.999616   0.030895  0.936672     0.515255      0.936672
# f1-score     0.966587   0.056138  0.936672     0.511362      0.909510
# support    981.000000  66.769231  0.936672  1047.769231   1047.769231
#  Test_auc_roc: 0.5152552421242975
#
# Epoch: 33, Loss:0.1603 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.961323   0.621532  0.930843    0.791427      0.941422
# recall       0.957677   0.669126  0.930843    0.813402      0.930843
# f1-score     0.958386   0.601312  0.930843    0.779849      0.930822
# support    792.096774  98.709677  0.930843  890.806452    890.806452
#  Train_auc_roc: 0.8134017364906365
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.912611    0.830724  0.913184     0.871668      0.917245
# recall       0.996226    0.168469  0.913184     0.582347      0.913184
# f1-score     0.951475    0.260041  0.913184     0.605758      0.888337
# support    942.200000  123.400000  0.913184  1065.600000   1065.600000
#  Val_auc_roc: 0.5823471720117742
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936140   0.348718  0.936128     0.642429      0.910204
# recall       0.999616   0.025589  0.936128     0.512603      0.936128
# f1-score     0.966314   0.047058  0.936128     0.506686      0.908335
# support    981.000000  66.769231  0.936128  1047.769231   1047.769231
#  Test_auc_roc: 0.5126027222303983
#
# Epoch: 34, Loss:0.1571 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.960869   0.623936  0.931498    0.792403      0.941560
# recall       0.958990   0.663969  0.931498    0.811480      0.931498
# f1-score     0.958815   0.600045  0.931498    0.779430      0.931045
# support    792.096774  98.709677  0.931498  890.806452    890.806452
#  Train_auc_roc: 0.8114798226419888
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.910699    0.804097  0.911203     0.857398      0.915341
# recall       0.996429    0.144580  0.911203     0.570505      0.911203
# f1-score     0.950451    0.223145  0.911203     0.586798      0.884730
# support    942.200000  123.400000  0.911203  1065.600000   1065.600000
#  Val_auc_roc: 0.5705047705508309
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935956   0.335897  0.935924     0.635927      0.908725
# recall       0.999616   0.023600  0.935924     0.511608      0.935924
# f1-score     0.966212   0.043339  0.935924     0.504775      0.907862
# support    981.000000  66.769231  0.935924  1047.769231   1047.769231
#  Test_auc_roc: 0.5116080272701862
#
# Epoch: 35, Loss:0.1556 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.960809   0.627830  0.932045    0.794320      0.942089
# recall       0.959783   0.663869  0.932045    0.811826      0.932045
# f1-score     0.959175   0.601347  0.932045    0.780261      0.931518
# support    792.096774  98.709677  0.932045  890.806452    890.806452
#  Train_auc_roc: 0.8118257503012102
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.909892    0.818651  0.910899     0.864272      0.916790
# recall       0.997081    0.134130  0.910899     0.565605      0.910899
# f1-score     0.950305    0.212449  0.910899     0.581377      0.883677
# support    942.200000  123.400000  0.910899  1065.600000   1065.600000
#  Val_auc_roc: 0.5656052672081419
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935956   0.335897  0.935924     0.635927      0.908725
# recall       0.999616   0.023600  0.935924     0.511608      0.935924
# f1-score     0.966212   0.043339  0.935924     0.504775      0.907862
# support    981.000000  66.769231  0.935924  1047.769231   1047.769231
#  Test_auc_roc: 0.5116080272701862
#
# Epoch: 36, Loss:0.1545 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.960803   0.629449  0.931877    0.795126      0.942323
# recall       0.959769   0.665273  0.931877    0.812521      0.931877
# f1-score     0.959140   0.601740  0.931877    0.780440      0.931410
# support    792.096774  98.709677  0.931877  890.806452    890.806452
#  Train_auc_roc: 0.8125210403848291
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.907943    0.818222  0.908696     0.863083      0.915167
# recall       0.997081    0.121707  0.908696     0.559394      0.908696
# f1-score     0.949138    0.194234  0.908696     0.571686      0.879931
# support    942.200000  123.400000  0.908696  1065.600000   1065.600000
#  Val_auc_roc: 0.5593937925756147
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935956   0.335897  0.935924     0.635927      0.908725
# recall       0.999616   0.023600  0.935924     0.511608      0.935924
# f1-score     0.966212   0.043339  0.935924     0.504775      0.907862
# support    981.000000  66.769231  0.935924  1047.769231   1047.769231
#  Test_auc_roc: 0.5116080272701862
#
# Epoch: 37, Loss:0.1529 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.961221   0.622835  0.930264    0.792028      0.941760
# recall       0.957304   0.669893  0.930264    0.813599      0.930264
# f1-score     0.958068   0.599297  0.930264    0.778682      0.930253
# support    792.096774  98.709677  0.930264  890.806452    890.806452
#  Train_auc_roc: 0.8135987645124806
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.908306    0.818222  0.909085     0.863264      0.915503
# recall       0.997081    0.127112  0.909085     0.562096      0.909085
# f1-score     0.949332    0.204221  0.909085     0.576777      0.880829
# support    942.200000  123.400000  0.909085  1065.600000   1065.600000
#  Val_auc_roc: 0.5620964952783174
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935956   0.335897  0.935924     0.635927      0.908725
# recall       0.999616   0.023600  0.935924     0.511608      0.935924
# f1-score     0.966212   0.043339  0.935924     0.504775      0.907862
# support    981.000000  66.769231  0.935924  1047.769231   1047.769231
#  Test_auc_roc: 0.5116080272701862
#
# Epoch: 38, Loss:0.1505 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.962407   0.616688  0.929032    0.789548      0.941919
# recall       0.954496   0.678381  0.929032    0.816438      0.929032
# f1-score     0.957215   0.599645  0.929032    0.778430      0.929850
# support    792.096774  98.709677  0.929032  890.806452    890.806452
#  Train_auc_roc: 0.8164384630465523
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.910505    0.828744  0.911437     0.869625      0.915575
# recall       0.996908    0.148006  0.911437     0.572457      0.911437
# f1-score     0.950581    0.234204  0.911437     0.592393      0.884782
# support    942.200000  123.400000  0.911437  1065.600000   1065.600000
#  Val_auc_roc: 0.5724567849742412
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935956   0.335897  0.935924     0.635927      0.908725
# recall       0.999616   0.023600  0.935924     0.511608      0.935924
# f1-score     0.966212   0.043339  0.935924     0.504775      0.907862
# support    981.000000  66.769231  0.935924  1047.769231   1047.769231
#  Test_auc_roc: 0.5116080272701862
#
# Epoch: 39, Loss:0.1505 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.963640   0.607820  0.927445    0.785730      0.941867
# recall       0.951361   0.685528  0.927445    0.818444      0.927445
# f1-score     0.956226   0.597943  0.927445    0.777084      0.929130
# support    792.096774  98.709677  0.927445  890.806452    890.806452
#  Train_auc_roc: 0.8184442643323119
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.911333    0.846581   0.91231     0.878957      0.917031
# recall       0.996908    0.163931   0.91231     0.580420      0.912310
# f1-score     0.951032    0.255299   0.91231     0.603166      0.886248
# support    942.200000  123.400000   0.91231  1065.600000   1065.600000
#  Val_auc_roc: 0.5804197094131383
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.935956   0.335897  0.935924     0.635927      0.908725
# recall       0.999616   0.023600  0.935924     0.511608      0.935924
# f1-score     0.966212   0.043339  0.935924     0.504775      0.907862
# support    981.000000  66.769231  0.935924  1047.769231   1047.769231
#  Test_auc_roc: 0.5116080272701862
#
# Epoch: 40, Loss:0.1469 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.964172   0.602826  0.926233    0.783499      0.941642
# recall       0.949285   0.692832  0.926233    0.821058      0.926233
# f1-score     0.955429   0.597219  0.926233    0.776324      0.928437
# support    792.096774  98.709677  0.926233  890.806452    890.806452
#  Train_auc_roc: 0.8210581471643452
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.913307    0.850967  0.914505     0.882137      0.919250
# recall       0.996908    0.178411  0.914505     0.587659      0.914505
# f1-score     0.952185    0.277544  0.914505     0.614865      0.890219
# support    942.200000  123.400000  0.914505  1065.600000   1065.600000
#  Val_auc_roc: 0.5876593956001928
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.936017   0.337729  0.935989     0.636873      0.908908
# recall       0.999616   0.024550  0.935989     0.512083      0.935989
# f1-score     0.966244   0.044987  0.935989     0.505615      0.908005
# support    981.000000  66.769231  0.935989  1047.769231   1047.769231
#  Test_auc_roc: 0.5120828610783532
#
# Epoch: 41, Loss:0.1470 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.964380   0.602052  0.926037    0.783216      0.941696
# recall       0.948843   0.693734  0.926037    0.821288      0.926037
# f1-score     0.955304   0.597098  0.926037    0.776201      0.928384
# ...
# precision    0.944376   0.328133  0.941646     0.636255      0.916513
# recall       0.995771   0.114330  0.941646     0.555050      0.941646
# f1-score     0.969019   0.162022  0.941646     0.565520      0.922258
# support    981.000000  66.769231  0.941646  1047.769231   1047.769231
#  Test_auc_roc: 0.5550504858293243
#
# Epoch: 188, Loss:0.0738 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.918917   0.525759  0.915021    0.722338      0.887589
# recall       0.991248   0.348656  0.915021    0.669952      0.915021
# f1-score     0.950824   0.383601  0.915021    0.667212      0.888857
# support    792.096774  98.709677  0.915021  890.806452    890.806452
#  Train_auc_roc: 0.6699524508257227
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.929446    0.711630  0.925087     0.820538      0.920795
# recall       0.987682    0.338666  0.925087     0.663174      0.925087
# f1-score     0.957126    0.452173  0.925087     0.704650      0.913790
# support    942.200000  123.400000  0.925087  1065.600000   1065.600000
#  Val_auc_roc: 0.6631740885973421
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.944047   0.330989  0.941557     0.637518      0.916498
# recall       0.996070   0.110442  0.941557     0.553256      0.941557
# f1-score     0.968984   0.158665  0.941557     0.563825      0.921922
# support    981.000000  66.769231  0.941557  1047.769231   1047.769231
#  Test_auc_roc: 0.5532562040755278
#
# Epoch: 189, Loss:0.0748 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.920288   0.524090  0.916078    0.722189      0.888506
# recall       0.990950   0.354730  0.916078    0.672840      0.916078
# f1-score     0.951439   0.387154  0.916078    0.669296      0.890191
# support    792.096774  98.709677  0.916078  890.806452    890.806452
#  Train_auc_roc: 0.6728399592334677
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.928999    0.697550  0.924515     0.813274      0.919605
# recall       0.987672    0.334932  0.924515     0.661302      0.924515
# f1-score     0.956873    0.447767  0.924515     0.702320      0.913065
# support    942.200000  123.400000  0.924515  1065.600000   1065.600000
#  Val_auc_roc: 0.6613017835686866
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943854   0.329257  0.941356     0.636555      0.916144
# recall       0.996070   0.108741  0.941356     0.552405      0.941356
# f1-score     0.968880   0.156520  0.941356     0.562700      0.921588
# support    981.000000  66.769231  0.941356  1047.769231   1047.769231
#  Test_auc_roc: 0.5524053701964511
#
# Epoch: 190, Loss:0.0722 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.918704   0.495493  0.915299    0.707099      0.880122
# recall       0.991933   0.346398  0.915299    0.669165      0.915299
# f1-score     0.951048   0.382295  0.915299    0.666672      0.888905
# support    792.096774  98.709677  0.915299  890.806452    890.806452
#  Train_auc_roc: 0.6691654128706256
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.927040    0.713081  0.923471     0.820061      0.919068
# recall       0.988909    0.307444  0.923471     0.648177      0.923471
# f1-score     0.956383    0.422817  0.923471     0.689600      0.910700
# support    942.200000  123.400000  0.923471  1065.600000   1065.600000
#  Val_auc_roc: 0.6481768379694631
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943417   0.327626  0.941132     0.635522      0.915529
# recall       0.996324   0.104466  0.941132     0.550395      0.941132
# f1-score     0.968766   0.151629  0.941132     0.560198      0.920966
# support    981.000000  66.769231  0.941132  1047.769231   1047.769231
#  Test_auc_roc: 0.5503949788278286
#
# Epoch: 191, Loss:0.0743 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.920722   0.490437  0.916362    0.705579      0.881195
# recall       0.990888   0.358730  0.916362    0.674809      0.916362
# f1-score     0.951599   0.389335  0.916362    0.670467      0.890507
# support    792.096774  98.709677  0.916362  890.806452    890.806452
#  Train_auc_roc: 0.6748093189730898
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.929742    0.719258  0.925504     0.824500      0.921231
# recall       0.987802    0.340349  0.925504     0.664076      0.925504
# f1-score     0.957350    0.455400  0.925504     0.706375      0.914293
# support    942.200000  123.400000  0.925504  1065.600000   1065.600000
#  Val_auc_roc: 0.6640756383001488
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943826   0.329959  0.941445     0.636893      0.916101
# recall       0.996216   0.108462  0.941445     0.552339      0.941445
# f1-score     0.968931   0.156296  0.941445     0.562614      0.921578
# support    981.000000  66.769231  0.941445  1047.769231   1047.769231
#  Test_auc_roc: 0.5523387533948427
#
# Epoch: 192, Loss:0.0724 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.921184   0.488068  0.916454    0.704626      0.881192
# recall       0.990427   0.360270  0.916454    0.675348      0.916454
# f1-score     0.951634   0.390127  0.916454    0.670881      0.890782
# support    792.096774  98.709677  0.916454  890.806452    890.806452
#  Train_auc_roc: 0.6753481443675599
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.929608    0.714161  0.925387     0.821884      0.921279
# recall       0.987855    0.339250  0.925387     0.663553      0.925387
# f1-score     0.957298    0.453142  0.925387     0.705220      0.914124
# support    942.200000  123.400000  0.925387  1065.600000   1065.600000
#  Val_auc_roc: 0.6635527675351238
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943810   0.326826  0.941275     0.635318      0.915713
# recall       0.996021   0.108462  0.941275     0.552241      0.941275
# f1-score     0.968833   0.155961  0.941275     0.562397      0.921446
# support    981.000000  66.769231  0.941275  1047.769231   1047.769231
#  Test_auc_roc: 0.5522412672577117
#
# Epoch: 193, Loss:0.0729 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.918276   0.495173  0.914964    0.706724      0.879803
# recall       0.991979   0.343742  0.914964    0.667860      0.914964
# f1-score     0.950855   0.379867  0.914964    0.665361      0.888471
# support    792.096774  98.709677  0.914964  890.806452    890.806452
#  Train_auc_roc: 0.6678601599236511
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.926296    0.716166  0.923181     0.821231      0.919304
# recall       0.989725    0.300851  0.923181     0.645288      0.923181
# f1-score     0.956327    0.416645  0.923181     0.686486      0.909877
# support    942.200000  123.400000  0.923181  1065.600000   1065.600000
#  Val_auc_roc: 0.6452878818694978
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943260   0.325999  0.941193     0.634630      0.915347
# recall       0.996643   0.102190  0.941193     0.549417      0.941193
# f1-score     0.968825   0.149620  0.941193     0.559222      0.920857
# support    981.000000  66.769231  0.941193  1047.769231   1047.769231
#  Test_auc_roc: 0.5494166363193715
#
# Epoch: 194, Loss:0.0724 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.921013   0.488021   0.91643    0.704517      0.881057
# recall       0.990669   0.356649   0.91643    0.673659      0.916430
# f1-score     0.951699   0.386434   0.91643    0.669066      0.890556
# support    792.096774  98.709677   0.91643  890.806452    890.806452
#  Train_auc_roc: 0.6736588896063368
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.928171    0.709259  0.924255     0.818715      0.919812
# recall       0.988414    0.321120  0.924255     0.654767      0.924255
# f1-score     0.956763    0.434456  0.924255     0.695609      0.912107
# support    942.200000  123.400000  0.924255  1065.600000   1065.600000
#  Val_auc_roc: 0.6547669443463559
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943568   0.328477  0.941212     0.636023      0.915779
# recall       0.996259   0.106389  0.941212     0.551324      0.941212
# f1-score     0.968812   0.154257  0.941212     0.561535      0.921230
# support    981.000000  66.769231  0.941212  1047.769231   1047.769231
#  Test_auc_roc: 0.5513241205556814
#
# Epoch: 195, Loss:0.0703 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.922977   0.485142  0.917948    0.704059      0.882296
# recall       0.990357   0.366640  0.917948    0.678499      0.917948
# f1-score     0.952596   0.392995  0.917948    0.672795      0.892433
# support    792.096774  98.709677  0.917948  890.806452    890.806452
#  Train_auc_roc: 0.6784986911468607
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.927942    0.706370  0.923653     0.817156      0.918896
# recall       0.987802    0.320021  0.923653     0.653912      0.923653
# f1-score     0.956373    0.432645  0.923653     0.694509      0.911477
# support    942.200000  123.400000  0.923653  1065.600000   1065.600000
#  Val_auc_roc: 0.6539116833993518
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943546   0.324306  0.940943     0.633926      0.915275
# recall       0.995951   0.106389  0.940943     0.551170      0.940943
# f1-score     0.968657   0.153349  0.940943     0.561003      0.920989
# support    981.000000  66.769231  0.940943  1047.769231   1047.769231
#  Test_auc_roc: 0.5511699583937533
#
# Epoch: 196, Loss:0.0722 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.919780   0.491829  0.915845    0.705804      0.880662
# recall       0.991432   0.349908  0.915845    0.670670      0.915845
# f1-score     0.951391   0.382287  0.915845    0.666839      0.889588
# support    792.096774  98.709677  0.915845  890.806452    890.806452
#  Train_auc_roc: 0.6706700730799631
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.925916    0.704402  0.922308     0.815159      0.918031
# recall       0.988994    0.299681  0.922308     0.644338      0.922308
# f1-score     0.955787    0.413285  0.922308     0.684536      0.908976
# support    942.200000  123.400000  0.922308  1065.600000   1065.600000
#  Val_auc_roc: 0.6443375746577695
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943232   0.321965  0.940888     0.632598      0.914731
# recall       0.996285   0.102190  0.940888     0.549238      0.940888
# f1-score     0.968645   0.148767  0.940888     0.558706      0.920579
# support    981.000000  66.769231  0.940888  1047.769231   1047.769231
#  Test_auc_roc: 0.5492377454428063
#
# Epoch: 197, Loss:0.0713 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.919424   0.490410  0.915289    0.704917      0.880189
# recall       0.991148   0.350539  0.915289    0.670844      0.915289
# f1-score     0.951028   0.382464  0.915289    0.666746      0.889025
# support    792.096774  98.709677  0.915289  890.806452    890.806452
#  Train_auc_roc: 0.6708438718582683
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.926349    0.690702  0.922526     0.808526      0.918187
# recall       0.988755    0.301950  0.922526     0.645352      0.922526
# f1-score     0.955916    0.412556  0.922526     0.684236      0.909433
# support    942.200000  123.400000  0.922526  1065.600000   1065.600000
#  Val_auc_roc: 0.6453524175437829
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943220   0.316863  0.940809     0.630041      0.914313
# recall       0.996191   0.102190  0.940809     0.549190      0.940809
# f1-score     0.968597   0.148035  0.940809     0.558316      0.920488
# support    981.000000  66.769231  0.940809  1047.769231   1047.769231
#  Test_auc_roc: 0.549190290691668
#
# Epoch: 198, Loss:0.0723 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.921042   0.485740  0.915975    0.703391      0.880891
# recall       0.990078   0.359457  0.915975    0.674767      0.915975
# f1-score     0.951360   0.387004  0.915975    0.669182      0.890149
# support    792.096774  98.709677  0.915975  890.806452    890.806452
#  Train_auc_roc: 0.6747673631040694
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.928337    0.693943  0.923841     0.811140      0.919583
# recall       0.987648    0.325427  0.923841     0.656537      0.923841
# f1-score     0.956493    0.435862  0.923841     0.696178      0.912066
# support    942.200000  123.400000  0.923841  1065.600000   1065.600000
#  Val_auc_roc: 0.6565372184236271
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943670   0.313439   0.94058     0.628555      0.914385
# recall       0.995376   0.107769   0.94058     0.551573      0.940580
# f1-score     0.968455   0.153762   0.94058     0.561108      0.920893
# support    981.000000  66.769231   0.94058  1047.769231   1047.769231
#  Test_auc_roc: 0.5515725192239108
#
# Epoch: 199, Loss:0.0692 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.919471   0.490430  0.915238    0.704950      0.880136
# recall       0.991007   0.348701  0.915238    0.669854      0.915238
# f1-score     0.951004   0.381018  0.915238    0.666011      0.888987
# support    792.096774  98.709677  0.915238  890.806452    890.806452
#  Train_auc_roc: 0.6698539371761868
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.926723    0.678079  0.922439     0.802401      0.917868
# recall       0.988108    0.304732  0.922439     0.646420      0.922439
# f1-score     0.955830    0.412239  0.922439     0.684035      0.909647
# support    942.200000  123.400000  0.922439  1065.600000   1065.600000
#  Val_auc_roc: 0.6464204397200592
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943399   0.321313  0.940791     0.632356      0.914888
# recall       0.995970   0.104466  0.940791     0.550218      0.940791
# f1-score     0.968588   0.151708  0.940791     0.560148      0.920815
# support    981.000000  66.769231  0.940791  1047.769231   1047.769231
#  Test_auc_roc: 0.5502177965619899
#
# Epoch: 200, Loss:0.0717 Train:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.920055   0.491413   0.91583    0.705734      0.880596
# recall       0.991028   0.350675   0.91583    0.670852      0.915830
# f1-score     0.951353   0.382634   0.91583    0.666993      0.889649
# support    792.096774  98.709677   0.91583  890.806452    890.806452
#  Train_auc_roc: 0.6708517787101588
#
# Valid:
#                     0           1  accuracy    macro avg  weighted avg
# precision    0.926867    0.683470  0.922705     0.805169      0.918112
# recall       0.988228    0.305831  0.922705     0.647030      0.922705
# f1-score     0.955968    0.414776  0.922705     0.685372      0.909960
# support    942.200000  123.400000  0.922705  1065.600000   1065.600000
#  Val_auc_roc: 0.647029591762047
#
# Test:
#                     0          1  accuracy    macro avg  weighted avg
# precision    0.943545   0.322525  0.940914     0.633035      0.915124
# recall       0.995934   0.106389  0.940914     0.551162      0.940914
# f1-score     0.968649   0.154089  0.940914     0.561369      0.921062
# support    981.000000  66.769231  0.940914  1047.769231   1047.769231
#  Test_auc_roc: 0.551161563532874
